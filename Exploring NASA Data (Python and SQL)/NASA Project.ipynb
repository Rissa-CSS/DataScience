# %% [markdown]
# # Exploring NASA Dataset

# %% [markdown]
# ## Installing modules

# %%
pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\ccall\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\ccall\anaconda3\lib\site-packages (from ipython-sql) (2.0.22)
# Requirement already satisfied: ipython in c:\users\ccall\anaconda3\lib\site-packages (from ipython-sql) (7.22.0)
# Requirement already satisfied: sqlparse in c:\users\ccall\anaconda3\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in c:\users\ccall\anaconda3\lib\site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: ipython-genutils in c:\users\ccall\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable in c:\users\ccall\anaconda3\lib\site-packages (from ipython-sql) (3.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ccall\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\ccall\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.8.0)
# Requirement already satisfied: pickleshare in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: colorama in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.17.2)
# Requirement already satisfied: pygments in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.17)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (52.0.0.post20210125)
# Requirement already satisfied: traitlets>=4.2 in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.0.5)
# Requirement already satisfied: backcall in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ccall\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.0.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\ccall\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\ccall\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-sql) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector
# Out:
# Requirement already satisfied: mysql-connector in c:\users\ccall\anaconda3\lib\site-packages (2.2.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysqlclient
# Out:
# Requirement already satisfied: mysqlclient in c:\users\ccall\anaconda3\lib\site-packages (2.2.0)Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importing CSV Datafile

# %%
#--- Import Pandas ---
import pandas as pd

#--- Read in dataset ----
df = pd.read_csv("nasa.csv")

#--- Inspect dataframe ---
df
# Out:
#                         Name  Year  GroupNum      Status  Birth_Date  \
# 0        Alan B. Shepard Jr.  1959         1    Deceased  18-11-1923
# 1         Alan G. Poindexter  1998        17    Deceased  05-11-1961
# 2               Alan L. Bean  1963         3    Deceased  15-03-1932
# 3           Albert Sacco Jr.  1963         3     Retired  03-05-1949
# 4           Alfred M. Worden  1966         5     Retired  07-02-1932
# ..                       ...   ...       ...         ...         ...
# 352      William M. Shepherd  1984        10     Retired  26-07-1949
# 353         William R. Pogue  1966         5     Retired  23-01-1930
# 354  William S. McArthur Jr.  1990         3  Management  26-07-1951
# 355         Winston E. Scott  1992        14     Retired  06-08-1950
# 356          Yvonne D. Cagle  1996        16  Management  24-04-1959
#
#         Birth_Place  Gender  \
# 0    East Derry, NH    Male
# 1      Pasadena, CA    Male
# 2       Wheeler, TX    Male
# 3        Boston, MA    Male
# 4       Jackson, MI    Male
# ..              ...     ...
# 352   Oak Ridge, TN    Male
# 353      Okemah, OK    Male
# 354  Laurinburg, NC    Male
# 355       Miami, FL    Male
# 356  West Point, NY  Female
#
#                                             Alma_Mater  \
# 0                                     US Naval Academy
# 1    Georgia Institute of Technology; US Naval Post...
# 2                                  University of Texas
# 3                         Northeastern University; MIT
# 4          US Military Academy; University of Michigan
# ..                                                 ...
# 352                              US Naval Academy; MIT
# 353  Oklahoma Baptist University; Oklahoma State Un...
# 354  US Military Academy; Georgia Institute of Tech...
# 355  Florida State University; US Naval Postgraduat...
# 356                     San Francisco State University
#
#                Undergraduate_Major                            Graduate_Major  \
# 0                   Naval Sciences                             Naval Science
# 1            Aerospace Engineering                  Aeronautical Engineering
# 2         Aeronautical Engineering                  Aeronautical Engineering
# 3             Chemical Engineering                      Chemical Engineering
# 4                 Military Science  Aeronautical & Astronautical Engineering
# ..                             ...                                       ...
# 352          Aerospace Engineering                   Mechanical  Engineering
# 353                      Education                               Mathematics
# 354  Applied Science & Engineering                     Aerospace Engineering
# 355                          Music                  Aeronautical Engineering
# 356                   Biochemistry                  Aeronautical Engineering
#
#     Military_Rank         Military_Branch  Space_Flights  Space_Flight_hr  \
# 0    Rear Admiral       US Navy (Retired)              2              216
# 1         Captain                 US Navy              2              669
# 2         Captain       US Navy (Retired)              2             1671
# 3         Captain       US Navy (Retired)              1              381
# 4         Colonel  US Air Force (Retired)              1              295
# ..            ...                     ...            ...              ...
# 352       Captain       US Navy (Retired)              4             3823
# 353       Colonel  US Air Force (Retired)              1             2017
# 354       Colonel       US Army (Retired)              4             5398
# 355       Captain       US Navy (Retired)              2              590
# 356       Colonel            US Air Force              0                0
#
#      Space_Walks  Space_Walks_hr  \
# 0              2             9.0
# 1              0             0.0
# 2              3            10.0
# 3              0             0.0
# 4              1             0.5
# ..           ...             ...
# 352            0             0.0
# 353            2            13.0
# 354            4            24.0
# 355            3            19.0
# 356            0             0.0
#
#                                               Missions  Death_Date  \
# 0                                 Mercury 3, Apollo 14  21-07-1998
# 1              STS-122 (Atlantis), STS-131 (Discovery)  01-07-2012
# 2                                  Apollo 12, Skylab 3  26-05-2018
# 3                                    STS-73 (Columbia)         NaN
# 4                                            Apollo 15         NaN
# ..                                                 ...         ...
# 352  STS-37 (Atlantis), STS-41 (Discovery), STS-52 ...         NaN
# 353                                           Skylab 4         NaN
# 354  STS-58 (Columbia), STS-74 (Atlantis), STS-92 (...         NaN
# 355               STS-72 (Endeavor), STS-87 (Columbia)         NaN
# 356               STS-72 (Endeavor), STS-87 (Columbia)         NaN
#
#                     Death_Mission
# 0                  Natural causes
# 1    Personal watercraft accident
# 2                  Natural causes
# 3                             NaN
# 4                             NaN
# ..                            ...
# 352                           NaN
# 353                           NaN
# 354                           NaN
# 355                           NaN
# 356                           NaN
#
# [357 rows x 19 columns]

# %% [markdown]
# ## Exploring Data Completeness

# %%
# Counting the null values in the data frame
null_values = df.isnull().sum()

#--- Inspecting data ---
null_values
# Out:
# Name                     0
# Year                     0
# GroupNum                 0
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               1
# Undergraduate_Major      0
# Graduate_Major           0
# Military_Rank            0
# Military_Branch          0
# Space_Flights            0
# Space_Flight_hr          0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                 0
# Death_Date             303
# Death_Mission          309
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
# Removes rows with no Alma_Mater
df.dropna(subset= ['Alma_Mater'], inplace=True)

# Removes columns with no death mission but a death date
df.drop(df[df['Death_Mission'].isnull() & df['Death_Date'].notnull()].index, inplace=True)

# Formats the date fields
df['Birth_Date'] =pd.to_datetime(df['Birth_Date'],dayfirst=True)
df['Death_Date'] =pd.to_datetime(df['Death_Date'],dayfirst=True)

#--- Inspect data ---
df
# Out:
#                         Name  Year  GroupNum      Status Birth_Date  \
# 0        Alan B. Shepard Jr.  1959         1    Deceased 1923-11-18
# 1         Alan G. Poindexter  1998        17    Deceased 1961-11-05
# 2               Alan L. Bean  1963         3    Deceased 1932-03-15
# 3           Albert Sacco Jr.  1963         3     Retired 1949-05-03
# 4           Alfred M. Worden  1966         5     Retired 1932-02-07
# ..                       ...   ...       ...         ...        ...
# 352      William M. Shepherd  1984        10     Retired 1949-07-26
# 353         William R. Pogue  1966         5     Retired 1930-01-23
# 354  William S. McArthur Jr.  1990         3  Management 1951-07-26
# 355         Winston E. Scott  1992        14     Retired 1950-08-06
# 356          Yvonne D. Cagle  1996        16  Management 1959-04-24
#
#         Birth_Place  Gender  \
# 0    East Derry, NH    Male
# 1      Pasadena, CA    Male
# 2       Wheeler, TX    Male
# 3        Boston, MA    Male
# 4       Jackson, MI    Male
# ..              ...     ...
# 352   Oak Ridge, TN    Male
# 353      Okemah, OK    Male
# 354  Laurinburg, NC    Male
# 355       Miami, FL    Male
# 356  West Point, NY  Female
#
#                                             Alma_Mater  \
# 0                                     US Naval Academy
# 1    Georgia Institute of Technology; US Naval Post...
# 2                                  University of Texas
# 3                         Northeastern University; MIT
# 4          US Military Academy; University of Michigan
# ..                                                 ...
# 352                              US Naval Academy; MIT
# 353  Oklahoma Baptist University; Oklahoma State Un...
# 354  US Military Academy; Georgia Institute of Tech...
# 355  Florida State University; US Naval Postgraduat...
# 356                     San Francisco State University
#
#                Undergraduate_Major                            Graduate_Major  \
# 0                   Naval Sciences                             Naval Science
# 1            Aerospace Engineering                  Aeronautical Engineering
# 2         Aeronautical Engineering                  Aeronautical Engineering
# 3             Chemical Engineering                      Chemical Engineering
# 4                 Military Science  Aeronautical & Astronautical Engineering
# ..                             ...                                       ...
# 352          Aerospace Engineering                   Mechanical  Engineering
# 353                      Education                               Mathematics
# 354  Applied Science & Engineering                     Aerospace Engineering
# 355                          Music                  Aeronautical Engineering
# 356                   Biochemistry                  Aeronautical Engineering
#
#     Military_Rank         Military_Branch  Space_Flights  Space_Flight_hr  \
# 0    Rear Admiral       US Navy (Retired)              2              216
# 1         Captain                 US Navy              2              669
# 2         Captain       US Navy (Retired)              2             1671
# 3         Captain       US Navy (Retired)              1              381
# 4         Colonel  US Air Force (Retired)              1              295
# ..            ...                     ...            ...              ...
# 352       Captain       US Navy (Retired)              4             3823
# 353       Colonel  US Air Force (Retired)              1             2017
# 354       Colonel       US Army (Retired)              4             5398
# 355       Captain       US Navy (Retired)              2              590
# 356       Colonel            US Air Force              0                0
#
#      Space_Walks  Space_Walks_hr  \
# 0              2             9.0
# 1              0             0.0
# 2              3            10.0
# 3              0             0.0
# 4              1             0.5
# ..           ...             ...
# 352            0             0.0
# 353            2            13.0
# 354            4            24.0
# 355            3            19.0
# 356            0             0.0
#
#                                               Missions Death_Date  \
# 0                                 Mercury 3, Apollo 14 1998-07-21
# 1              STS-122 (Atlantis), STS-131 (Discovery) 2012-07-01
# 2                                  Apollo 12, Skylab 3 2018-05-26
# 3                                    STS-73 (Columbia)        NaT
# 4                                            Apollo 15        NaT
# ..                                                 ...        ...
# 352  STS-37 (Atlantis), STS-41 (Discovery), STS-52 ...        NaT
# 353                                           Skylab 4        NaT
# 354  STS-58 (Columbia), STS-74 (Atlantis), STS-92 (...        NaT
# 355               STS-72 (Endeavor), STS-87 (Columbia)        NaT
# 356               STS-72 (Endeavor), STS-87 (Columbia)        NaT
#
#                     Death_Mission
# 0                  Natural causes
# 1    Personal watercraft accident
# 2                  Natural causes
# 3                             NaN
# 4                             NaN
# ..                            ...
# 352                           NaN
# 353                           NaN
# 354                           NaN
# 355                           NaN
# 356                           NaN
#
# [350 rows x 19 columns]

# %% [markdown]
# ## Preparing Data for SQL Analysis

# %%
# Export the cleaned data
df.to_csv('astronauts.csv',index=False)

#--- Inspect data ---
df
# Out:
#                         Name  Year  GroupNum      Status Birth_Date  \
# 0        Alan B. Shepard Jr.  1959         1    Deceased 1923-11-18
# 1         Alan G. Poindexter  1998        17    Deceased 1961-11-05
# 2               Alan L. Bean  1963         3    Deceased 1932-03-15
# 3           Albert Sacco Jr.  1963         3     Retired 1949-05-03
# 4           Alfred M. Worden  1966         5     Retired 1932-02-07
# ..                       ...   ...       ...         ...        ...
# 352      William M. Shepherd  1984        10     Retired 1949-07-26
# 353         William R. Pogue  1966         5     Retired 1930-01-23
# 354  William S. McArthur Jr.  1990         3  Management 1951-07-26
# 355         Winston E. Scott  1992        14     Retired 1950-08-06
# 356          Yvonne D. Cagle  1996        16  Management 1959-04-24
#
#         Birth_Place  Gender  \
# 0    East Derry, NH    Male
# 1      Pasadena, CA    Male
# 2       Wheeler, TX    Male
# 3        Boston, MA    Male
# 4       Jackson, MI    Male
# ..              ...     ...
# 352   Oak Ridge, TN    Male
# 353      Okemah, OK    Male
# 354  Laurinburg, NC    Male
# 355       Miami, FL    Male
# 356  West Point, NY  Female
#
#                                             Alma_Mater  \
# 0                                     US Naval Academy
# 1    Georgia Institute of Technology; US Naval Post...
# 2                                  University of Texas
# 3                         Northeastern University; MIT
# 4          US Military Academy; University of Michigan
# ..                                                 ...
# 352                              US Naval Academy; MIT
# 353  Oklahoma Baptist University; Oklahoma State Un...
# 354  US Military Academy; Georgia Institute of Tech...
# 355  Florida State University; US Naval Postgraduat...
# 356                     San Francisco State University
#
#                Undergraduate_Major                            Graduate_Major  \
# 0                   Naval Sciences                             Naval Science
# 1            Aerospace Engineering                  Aeronautical Engineering
# 2         Aeronautical Engineering                  Aeronautical Engineering
# 3             Chemical Engineering                      Chemical Engineering
# 4                 Military Science  Aeronautical & Astronautical Engineering
# ..                             ...                                       ...
# 352          Aerospace Engineering                   Mechanical  Engineering
# 353                      Education                               Mathematics
# 354  Applied Science & Engineering                     Aerospace Engineering
# 355                          Music                  Aeronautical Engineering
# 356                   Biochemistry                  Aeronautical Engineering
#
#     Military_Rank         Military_Branch  Space_Flights  Space_Flight_hr  \
# 0    Rear Admiral       US Navy (Retired)              2              216
# 1         Captain                 US Navy              2              669
# 2         Captain       US Navy (Retired)              2             1671
# 3         Captain       US Navy (Retired)              1              381
# 4         Colonel  US Air Force (Retired)              1              295
# ..            ...                     ...            ...              ...
# 352       Captain       US Navy (Retired)              4             3823
# 353       Colonel  US Air Force (Retired)              1             2017
# 354       Colonel       US Army (Retired)              4             5398
# 355       Captain       US Navy (Retired)              2              590
# 356       Colonel            US Air Force              0                0
#
#      Space_Walks  Space_Walks_hr  \
# 0              2             9.0
# 1              0             0.0
# 2              3            10.0
# 3              0             0.0
# 4              1             0.5
# ..           ...             ...
# 352            0             0.0
# 353            2            13.0
# 354            4            24.0
# 355            3            19.0
# 356            0             0.0
#
#                                               Missions Death_Date  \
# 0                                 Mercury 3, Apollo 14 1998-07-21
# 1              STS-122 (Atlantis), STS-131 (Discovery) 2012-07-01
# 2                                  Apollo 12, Skylab 3 2018-05-26
# 3                                    STS-73 (Columbia)        NaT
# 4                                            Apollo 15        NaT
# ..                                                 ...        ...
# 352  STS-37 (Atlantis), STS-41 (Discovery), STS-52 ...        NaT
# 353                                           Skylab 4        NaT
# 354  STS-58 (Columbia), STS-74 (Atlantis), STS-92 (...        NaT
# 355               STS-72 (Endeavor), STS-87 (Columbia)        NaT
# 356               STS-72 (Endeavor), STS-87 (Columbia)        NaT
#
#                     Death_Mission
# 0                  Natural causes
# 1    Personal watercraft accident
# 2                  Natural causes
# 3                             NaN
# 4                             NaN
# ..                            ...
# 352                           NaN
# 353                           NaN
# 354                           NaN
# 355                           NaN
# 356                           NaN
#
# [350 rows x 19 columns]

# %% [markdown]
# # SQL Analysis

# %% [markdown]
# ## SQL Connection

# %%
# Load the sql extention
#Use %load if this is the first time running else use %reload

#%load_ext sql 
# %reload_ext sql

# Connection string to SQL DB
connection_url = 'mysql://{user}:{password}@localhost/{db}'.format(user=user,password=password,db=db_name)
# %sql {connection_url}

# %% [markdown]
# ## SQL Queries

# %% [markdown]
# ### Retrieving all the data from the database.

# %%
# %%sql
# SELECT * FROM astronauts;
# Out:
#  * mysql://root:***@localhost/nasa
# 350 rows affected.
# [('Alan B. Shepard Jr.', 1959, 1, 'Deceased', '1923-11-18', 'East Derry, NH', 'Male', 'US Naval Academy', 'Naval Sciences', 'Naval Science', 'Rear Admiral', 'US Navy (Retired)', 2, 216, 2, Decimal('9.0'), 'Mercury 3, Apollo 14', '1998-07-21', 'Natural causes'),
#  ('Alan G. Poindexter', 1998, 17, 'Deceased', '1961-11-05', 'Pasadena, CA', 'Male', 'Georgia Institute of Technology; US Naval Postgraduate School', 'Aerospace Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy', 2, 669, 0, Decimal('0.0'), 'STS-122 (Atlantis), STS-131 (Discovery)', '2012-07-01', 'Personal watercraft accident'),
#  ('Alan L. Bean', 1963, 3, 'Deceased', '1932-03-15', 'Wheeler, TX', 'Male', 'University of Texas', 'Aeronautical Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 2, 1671, 3, Decimal('10.0'), 'Apollo 12, Skylab 3', '2018-05-26', 'Natural causes'),
#  ('Albert Sacco Jr.', 1963, 3, 'Retired', '1949-05-03', 'Boston, MA', 'Male', 'Northeastern University; MIT', 'Chemical Engineering', 'Chemical Engineering', 'Captain', 'US Navy (Retired)', 1, 381, 0, Decimal('0.0'), 'STS-73 (Columbia)', '', ''),
#  ('Alfred M. Worden', 1966, 5, 'Retired', '1932-02-07', 'Jackson, MI', 'Male', 'US Military Academy; University of Michigan', 'Military Science', 'Aeronautical & Astronautical Engineering', 'Colonel', 'US Air Force (Retired)', 1, 295, 1, Decimal('0.5'), 'Apollo 15', '', ''),
#  ('Alvin B. Drew Jr.', 2000, 18, 'Active', '1962-11-05', 'Washington, DC', 'Male', 'US Air Force Academy; Embry-Riddle Aeronautical University', 'Physics & Astronautical Engineering', 'Aerospace Science; Political Science', 'Colonel', 'US Air Force', 2, 613, 2, Decimal('13.0'), 'STS-118 (Endeavor), STS-133 (Discovery)', '', ''),
#  ('Andrew J. Feustel', 2000, 18, 'Active', '1965-08-25', 'Lancaster, PA', 'Male', 'Purdue University; Queen’s University-Canada', 'Solid Earth Sciences', 'Geophysics; Seismology', 'Colonel', 'US Air Force', 2, 687, 6, Decimal('42.0'), 'STS-125 (Atlantis), STS-134 (Endeavor)', '', ''),
#  ('Andrew M. Allen', 1987, 12, 'Retired', '1955-08-04', 'Philadelphia, PA', 'Male', 'Villanova University; University of Florida', 'Mechanical Engineering', 'Business Administration', 'Lieutenant Colonel', 'US Marine Corps (Retired)', 3, 906, 0, Decimal('0.0'), 'STS-46 (Atlantis), STS-62 (Columbia), STS-75 (Columbia)', '', ''),
#  ('Andrew S. W. Thomas', 1992, 14, 'Management', '1951-12-18', 'Adelaide, Australia', 'Male', 'University of Adelaide', 'Mechanical Engineering', 'Mechanical Engineering', 'Lieutenant Colonel', 'US Marine Corps (Retired)', 4, 4257, 1, Decimal('6.0'), 'STS-77 (Endeavor), STS-89/91 (Endeavor/Discovery), STS-102 (Discovery), STS-114 (Discovery)', '', ''),
#  ('Anna L. Fisher', 1978, 8, 'Management', '1949-08-24', 'New York, NY', 'Female', 'University of California-Los Angeles', 'Chemistry', 'Chemistry; Medicine', 'Lieutenant Colonel', 'US Marine Corps (Retired)', 1, 191, 0, Decimal('0.0'), 'STS 51-A (Discovery)', '', ''),
#  ('Anthony W. England', 1967, 6, 'Retired', '1942-05-15', 'Indianapolis, IN', 'Male', 'MIT', 'Geology', 'Geology; Geophysics', 'Lieutenant Colonel', 'US Marine Corps (Retired)', 1, 190, 0, Decimal('0.0'), 'STS 51-F (Challenger)', '', ''),
#  ('Barbara R. Morgan', 1998, 17, 'Retired', '1951-11-28', 'Fresno, CA', 'Female', 'Stanford University', 'Human Biology', 'Geology; Geophysics', 'Lieutenant Colonel', 'US Marine Corps (Retired)', 1, 305, 0, Decimal('0.0'), 'STS-118 (Endeavor)', '', ''),
#  ('Barry E. Wilmore', 2000, 18, 'Active', '1962-12-29', 'Murfreesboro, TN', 'Male', 'Tennessee Technological University; University of Tennessee', 'Electrical Engineering', 'Electrical Engineering; Aviation Systems', 'Captain', 'US Navy', 2, 4272, 4, Decimal('25.0'), 'STS-129 (Atlantis), ISS-41/42 (Soyuz)', '', ''),
#  ('Bernard A. Harris Jr.', 1990, 13, 'Retired', '1956-06-26', 'Temple, TX', 'Male', 'University of Houston; Texas Tech University', 'Biology', 'Medicine', 'Captain', 'US Navy', 2, 438, 1, Decimal('5.0'), 'STS-55 (Columbia), STS-63 (Discovery)', '', ''),
#  ('Bill Nelson', 1990, 13, 'Retired', '1942-09-29', 'Miami, FL', 'Male', 'Yale University; University of Virginia', 'Biology', 'Law', 'Captain', 'US Army (Retired)', 1, 146, 0, Decimal('0.0'), 'STS 61-C (Columbia)', '', ''),
#  ('Bonnie J. Dunbar', 1980, 9, 'Retired', '1949-03-03', 'Sunnyside, WA', 'Female', 'University of Washington; University of Houston', 'Ceramic Engineering', 'Ceramic Engineering; Biomedical Engineering', 'Captain', 'US Army (Retired)', 5, 1207, 0, Decimal('0.0'), 'STS 61-A (Challenger), STS-32 (Columbia), STS-50 (Columbia), STS-71 (Atlantis), STS-89 (Endeavor)', '', ''),
#  ('Brent W. Jett', 1992, 14, 'Retired', '1958-10-05', 'Pontiac, MI', 'Male', 'US Naval Academy; US Naval Postgraduate School', 'Aerospace Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 4, 1002, 0, Decimal('0.0'), 'STS-72 (Endeavor), STS-81 (Atlantis), STS-97 (Endeavor), STS-115 (Atlantis)', '', ''),
#  ('Brewster H. Shaw Jr.', 1978, 8, 'Retired', '1945-05-16', 'Cass City, MI', 'Male', 'University of Wisconsin', 'Engineering Mechanics', 'Engineering Mechanics', 'Colonel', 'US Air Force (Retired)', 3, 533, 0, Decimal('0.0'), 'STS-9 (Columbia), STS 61-B (Atlantis), STS-28 (Columbia)', '', ''),
#  ('Brian Duffy', 1985, 11, 'Retired', '1953-06-20', 'Boston, MA', 'Male', 'US Air Force Academy; University of Southern California', 'Mathematics', 'Systems Management', 'Colonel', 'US Air Force (Retired)', 4, 977, 0, Decimal('0.0'), 'STS-45 (Atlantis), STS-57 (Endeavor), STS-72 (Endeavor), STS-92 (Discovery)', '', ''),
#  ("Brian T. O'Leary", 1967, 6, 'Deceased', '1940-01-27', 'Boston, MA', 'Male', 'Williams College; Georgetown University; University of California-Berkeley', 'Physics', 'Astronomy', 'Colonel', 'US Air Force (Retired)', 0, 0, 0, Decimal('0.0'), 'STS-45 (Atlantis), STS-57 (Endeavor), STS-72 (Endeavor), STS-92 (Discovery)', '2011-07-28', 'Due to cancer'),
#  ('Bruce E. Melnick', 1987, 12, 'Retired', '1949-12-05', 'New York, NY', 'Male', 'US Coast Guard Academy; West Florida University', 'Engineering', 'Aeronautical Systems', 'Commander', 'US Coast Guard (Retired)', 2, 311, 0, Decimal('0.0'), 'STS-41 (Discovery), STS-49 (Endeavor)', '', ''),
#  ('Bruce McCandless II', 1966, 5, 'Retired', '1937-06-08', 'Boston, MA', 'Male', 'US Naval Academy; Stanford University; University of Houston-Clear Lake', 'Engineering', 'Electrical Engineering; Business Administration', 'Captain', 'US Navy (Retired)', 2, 312, 2, Decimal('12.0'), 'STS 41-B (Challenger), STS-31 (Discovery)', '', ''),
#  ("Bryan D. O'Connor", 1980, 9, 'Retired', '1946-09-06', 'Orange, CA', 'Male', 'US Naval Academy; West Florida University', 'Engineering', 'Aeronautical Systems', 'Colonel', 'US Marine Corps (Retired)', 2, 383, 0, Decimal('0.0'), 'STS 61-B (Atlantis), STS-40 (Columbia)', '', ''),
#  ('Buzz Aldrin', 1963, 3, 'Retired', '1930-01-20', 'Montclair, NJ', 'Male', 'US Military Academy; MIT', 'Mechanical Engineering', 'Astronautics', 'Colonel', 'US Air Force (Retired)', 2, 289, 2, Decimal('8.0'), 'Gemini 12, Apollo 11', '', ''),
#  ('Byron K. Lichtenberg', 1963, 3, 'Retired', '1948-02-19', 'Stroudsburg, PA', 'Male', 'Brown University; MIT', 'Aerospace Engineering', 'Mechanical Engineering; Biomedical Engineering', 'Colonel', 'US Air Force (Retired)', 2, 461, 0, Decimal('0.0'), 'STS-9 (Columbia), STS-45 (Atlantis)', '', ''),
#  ('C. Gordon Fullerton', 1969, 7, 'Retired', '1936-10-11', 'Rochester, NY', 'Male', 'California Institute of Technology', 'Mechanical Engineering', 'Mechanical Engineering', 'Colonel', 'US Air Force (Retired)', 2, 382, 0, Decimal('0.0'), 'STS-3 (Columbia), STS 51-F (Challenger)', '', ''),
#  ('C. Michael Foale', 1987, 12, 'Active', '1957-01-06', 'Louth, England', 'Male', 'Cambridge University', 'Physics', 'Laboratory Astrophysics', 'Colonel', 'US Air Force (Retired)', 6, 8970, 4, Decimal('22.0'), 'STS-45 (Atlantis), STS-56 (Discovery), STS-63 (Discovery), STS-84/86 (Atlantis), STS-103 (Discovery), ISS-08 (Soyuz)', '', ''),
#  ('Carl E. Walz', 1990, 13, 'Retired', '1955-09-06', 'Cleveland, OH', 'Male', 'Kent State University; John Carroll University', 'Physics', 'Solid State Physics', 'Colonel', 'US Air Force', 4, 5533, 3, Decimal('19.0'), 'STS-51 (Discovery), STS-65 (Columbia), STS-79 (Atlantis), STS-108/111 (Endeavor)', '', ''),
#  ('Carl J. Meade', 1985, 11, 'Retired', '1950-11-16', 'Chanute Air Force Base, IL', 'Male', 'University of Texas; California Institute of Technology', 'Electronics Engineering', 'Electronics Engineering', 'Colonel', 'US Air Force (Retired)', 3, 712, 1, Decimal('6.0'), 'STS-38 (Atlantis), STS-50 (Columbia), STS-64 (Discovery)', '', ''),
#  ('Carlos I. Noriega', 1995, 15, 'Retired', '1959-10-08', 'Lima, Peru', 'Male', 'University of Southern California; US Naval Postgraduate School', 'Computer Science', 'Computer Science; Space Systems Operations', 'Lieutenant Colonel', 'US Marine Corps (Retired)', 2, 481, 3, Decimal('19.0'), 'STS-84 (Atlantis), STS-97 (Endeavor)', '', ''),
#  ('Catherine G. Coleman', 1992, 14, 'Active', '1960-12-14', 'Charleston, SC', 'Female', 'MIT; University of Massachusetts', 'Chemistry', 'Polymer Science & Engineering', 'Colonel', 'US Air Force (Retired)', 3, 4324, 0, Decimal('0.0'), 'STS-73 (Columbia), STS-93 (Columbia), ISS-26/27 (Soyuz)', '', ''),
#  ('Charles A. Bassett II', 1963, 3, 'Deceased', '1931-12-30', 'Dayton, OH', 'Male', 'Texas Technological College', 'Electrical Engineering', 'Polymer Science & Engineering', 'Captain', 'US Air Force', 0, 0, 0, Decimal('0.0'), 'STS-73 (Columbia), STS-93 (Columbia), ISS-26/27 (Soyuz)', '1966-02-28', 'T-38 Talon jet aircraft'),
#  ('Charles Conrad Jr.', 1962, 2, 'Deceased', '1930-05-02', 'Philadelphia, PA', 'Male', 'Princeton University', 'Aeronautical Engineering', 'Polymer Science & Engineering', 'Captain', 'US Navy (Retired)', 4, 1179, 4, Decimal('12.0'), 'Gemini 5, Gemini 11, Apollo 12, Skylab 2', '1999-07-08', 'Motorcycle accident'),
#  ('Charles D. Gemar', 1985, 11, 'Retired', '1955-08-04', 'Yanktown, SD', 'Male', 'US Military Academy', 'Engineering', 'Polymer Science & Engineering', 'Lieutenant Colonel', 'US Army', 3, 581, 0, Decimal('0.0'), 'STS-38 (Atlantis), STS-48 (Discovery), STS-62 (Columbia)', '', ''),
#  ('Charles D. Walker', 1985, 11, 'Retired', '1948-08-29', 'Bedford, IN', 'Male', 'Purdue University', 'Aeronautical & Astronautical Engineering', 'Polymer Science & Engineering', 'Lieutenant Colonel', 'US Army', 3, 477, 0, Decimal('0.0'), 'STS 41-D (Discovery), STS 51-D (Discovery), STS 61-B (Atlantis)', '', ''),
#  ('Charles E. Brady Jr.', 1992, 14, 'Deceased', '1951-08-12', 'Pinehurst, NC', 'Male', 'University of North Carolina at Chapel Hill; Duke University', 'Aeronautical & Astronautical Engineering', 'Medicine', 'Captain', 'US Navy', 1, 405, 0, Decimal('0.0'), 'STS-78 (Columbia)', '2006-07-23', 'Natural causes'),
#  ('Charles F. Bolden Jr.', 1980, 9, 'Management', '1946-08-19', 'Columbia, SC', 'Male', 'US Naval Academy; University of Southern California', 'Electrical Science', 'Systems Management', 'Major General', 'US Marine Corps (Retired)', 4, 680, 0, Decimal('0.0'), 'STS-61C (Columbia), STS-31 (Discovery), STS-45 (Atlantis), STS-60 (Discovery)', '', ''),
#  ('Charles J. Camarda', 1996, 16, 'Management', '1952-05-08', 'Queens, NY', 'Male', 'Polytechnic Institute of Brooklyn; George Washington University; Virginia Polytechnic Institute', 'Aerospace Engineering', 'Engineering Science; Aerospace Engineering', 'Major General', 'US Marine Corps (Retired)', 1, 333, 0, Decimal('0.0'), 'STS-114 (Discovery)', '', ''),
#  ('Charles J. Precourt', 1990, 13, 'Retired', '1955-06-29', 'Waltham, MA', 'Male', 'US Air Force Academy; Golden Gate University; US Naval War College', 'Aeronautical Engineering', 'Engineering Management; Strategic Studies', 'Colonel', 'US Air Force (Retired)', 4, 950, 0, Decimal('0.0'), 'STS-55 (Columbia), STS-71 (Atlantis), STS-84 (Atlantis), STS-91 (Discovery)', '', ''),
#  ('Charles Lacy Veach', 1984, 10, 'Deceased', '1944-09-18', 'Chicago, IL', 'Male', 'US Air Force Academy', 'Engineering Management', 'Engineering Management; Strategic Studies', 'Colonel', 'US Air Force (Retired)', 2, 436, 0, Decimal('0.0'), 'STS-39 (Discovery), STS-52 (Columbia)', '2012-07-01', 'Due to cancer'),
#  ('Charles M. Duke Jr.', 1966, 5, 'Retired', '1935-10-03', 'Charlotte, NC', 'Male', 'US Naval Academy; MIT', 'Naval Sciences', 'Aeronautics', 'Brigadier General', 'US Air Force (Retired)', 1, 265, 3, Decimal('20.0'), 'Apollo 16', '', ''),
#  ('Charles O. Hobaugh', 1996, 16, 'Retired', '1961-11-05', 'Bar Harbor, ME', 'Male', 'US Naval Academy', 'Aerospace Engineering', 'Aeronautics', 'Colonel', 'US Marine Corps (Retired)', 3, 873, 0, Decimal('0.0'), 'STS-104 (Atlantis), STS-118 (Endeavor), ST-129 (Atlantis)', '', ''),
#  ('Christopher J. Cassidy', 2004, 19, 'Active', '1970-01-04', 'Salem, MA', 'Male', 'US Naval Academy; MIT', 'Mathematics', 'Ocean Engineering', 'Commander', 'US Navy', 1, 4376, 6, Decimal('31.0'), 'STS-127 (Endeavor); ISS-35/36 (Soyuz)', '', ''),
#  ('Christopher J. Ferguson', 1998, 17, 'Retired', '1961-09-01', 'Philadelphia, PA', 'Male', 'Drexel University; US Naval Postgraduate School', 'Mechanical Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 3, 970, 0, Decimal('0.0'), 'STS-115 (Atlantis), STS-126 (Endeavor), STS-135 (Atlantis)', '', ''),
#  ('Christopher J. Loria', 1996, 16, 'Retired', '1960-07-09', 'Belmont, MA', 'Male', 'US Naval Academy; Harvard University', 'Engineering', 'Public Administration', 'Colonel', 'US Marine Corps (Retired)', 0, 0, 0, Decimal('0.0'), 'STS-115 (Atlantis), STS-126 (Endeavor), STS-135 (Atlantis)', '', ''),
#  ('Clayton C. Anderson', 1998, 17, 'Retired', '1959-02-23', 'Omaha, NE', 'Male', 'Hastings College; Iowa State University', 'Physics', 'Aerospace Engineering', 'Colonel', 'US Marine Corps (Retired)', 2, 4005, 6, Decimal('38.0'), 'STS-117/120 (Atlantis/Discovery), STS-131 (Discovery)', '', ''),
#  ('Clifton C. Williams Jr.', 1963, 3, 'Deceased', '1932-09-26', 'Mobile, AL', 'Male', 'Auburn University', 'Mechanical Engineering', 'Aerospace Engineering', 'Major', 'US Marine Corps', 0, 0, 0, Decimal('0.0'), 'STS-117/120 (Atlantis/Discovery), STS-131 (Discovery)', '1967-10-05', 'T-38 jet trainer crash'),
#  ('Curtis L. Brown Jr.', 1987, 12, 'Retired', '1956-03-11', 'Elizabethtown, NC', 'Male', 'US Air Force Academy', 'Electrical Engineering', 'Aerospace Engineering', 'Colonel', 'US Air Force (Retired)', 6, 1383, 0, Decimal('0.0'), 'STS-47 (Endeavor), STS-66 (Atlantis), STS-77 (Endeavor), STS-85 (Discovery), STS-95 (Discovery), STS-103 (Discovery)', '', ''),
#  ('Dale A. Gardner', 1978, 8, 'Retired', '1948-11-08', 'Fairmont, MN', 'Male', 'University of Illinois', 'Engineering Physics', 'Aerospace Engineering', 'Captain', 'US Navy (Retired)', 2, 336, 2, Decimal('12.0'), 'STS-8 (Challenger), STS 51-A (Discovery)', '', ''),
#  ('Daniel C. Brandenstein', 1978, 8, 'Retired', '1943-01-17', 'Watertown, WI', 'Male', 'University of Wisconsin', 'Mathematics & Physics', 'Aerospace Engineering', 'Captain', 'US Navy (Retired)', 4, 789, 0, Decimal('0.0'), 'STS-8 (Challenger), STS 51-G (Discovery), STS-32 (Columbia), STS-49 (Endeavor)', '', ''),
#  ('Daniel C. Burbank', 1996, 16, 'Active', '1961-07-27', 'Machester, CT', 'Male', 'US Coast Guard Academy; Embry-Riddle Aeronautical University', 'Electrical Engineering', 'Aeronautical Science', 'Captain', 'US Coast Guard (Retired)', 3, 4512, 1, Decimal('7.0'), 'STS-106 (Atlantis), STS-115 (Atlantis), ISS-29/30 (Soyuz)', '', ''),
#  ('Daniel M. Tani', 1996, 16, 'Retired', '1961-02-01', 'Ridley Park, PA', 'Male', 'MIT', 'Mechanical Engineering', 'Mechanical Engineering', 'Captain', 'US Coast Guard (Retired)', 2, 3162, 6, Decimal('39.0'), 'STS-108 (Endeavor), STS-120/122 (Discovery/Atlantis)', '', ''),
#  ('Daniel T. Barry', 1992, 14, 'Retired', '1953-12-30', 'Norwalk, CT', 'Male', 'Cornell University; Princeton University; University of Miami', 'Electrical Engineering', 'Electrical Engineering; Computer Science; Medicine', 'Captain', 'US Coast Guard (Retired)', 3, 733, 4, Decimal('26.0'), 'STS-72 (Endeavor), STS-96 (Discovery), STS-105 (Discovery)', '', ''),
#  ('Daniel W. Bursch', 1990, 13, 'Retired', '1957-07-25', 'Bristol, PA', 'Male', 'US Naval Academy; US Naval Postgraduate School', 'Physics', 'Engineering Science', 'Captain', 'US Navy (Retired)', 4, 5446, 2, Decimal('12.0'), 'STS-51 (Discovery), STS-68 (Endeavor), STS-77 (Endeavor), STS-108/111 (Endeavor)', '', ''),
#  ('David A. Wolf', 1990, 13, 'Retired', '1956-08-23', 'Indianapolis, IN', 'Male', 'Purdue University; Indiana University', 'Electrical Engineering', 'Medicine', 'Captain', 'US Navy (Retired)', 3, 4044, 7, Decimal('41.0'), 'STS-58 (Columbia). STS-86/89 (Atlantis/Endeavor), STS-112 (Atlantis), STS-127 (Endeavor)', '', ''),
#  ('David C. Hilmers', 1980, 9, 'Retired', '1950-01-28', 'Clinton, IA', 'Male', 'Cornell University; US Naval Postgraduate School', 'Mathematics', 'Electrical Engineering', 'Colonel', 'US Marine Corps (Retired)', 4, 494, 0, Decimal('0.0'), 'ST 51-J (Atlantis), STS-26 (Discovery), STS-36 (Atlantis), STS-42 (Discovery)', '', ''),
#  ('David C. Leestma', 1980, 9, 'Management', '1949-05-06', 'Muskegon, MI', 'Male', 'US Naval Academy; US Naval Postgraduate School', 'Aeronautical Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 3, 532, 1, Decimal('3.0'), 'STS 41-G (Challenger), STS-28 (Columbia), STS-45 (Atlantis)', '', ''),
#  ('David M. Brown', 1996, 16, 'Deceased', '1956-04-16', 'Arlington, VA', 'Male', 'College of William & Mary; Eastern Virginia Medical School', 'Biology', 'Medicine', 'Captain', 'US Navy', 1, 382, 0, Decimal('0.0'), 'STS-107 (Columbia)', '2003-02-01', 'STS-107 (Columbia)'),
#  ('David M. Walker', 1978, 8, 'Deceased', '1944-05-20', 'Columbus, GA', 'Male', 'US Naval Academy', 'Naval Sciences', 'Medicine', 'Captain', 'US Navy (Retired)', 4, 724, 0, Decimal('0.0'), 'STS 51-A (Discovery), STS-30 (Atlantis), STS-53 (Discovery), STS-69 (Endeavor)', '2001-04-23', 'Plane crash'),
#  ('David R. Scott', 1963, 3, 'Retired', '1932-06-06', 'San Antonio, TX', 'Male', 'US Military Academy; MIT', 'Naval Sciences', 'Aeronautics & Astronautics', 'Colonel', 'US Air Force (Retired)', 3, 546, 4, Decimal('19.0'), 'Gemini 8, Apollo 9, Apollo 15', '', ''),
#  ('Dominic A. Antonelli', 2000, 18, 'Active', '1967-08-23', 'Detroit, MI', 'Male', 'MIT; University of Washington', 'Aeronautics & Astronautics', 'Aeronautics & Astronautics', 'Commander', 'US Navy', 2, 579, 0, Decimal('0.0'), 'STS-119 (Discovery), STS-132 (Atlantis)', '', ''),
#  ('Dominic L. Gorie', 1995, 15, 'Retired', '1957-05-02', 'Lake Charles, LA', 'Male', 'US Naval Academy; University of Tennessee', 'Ocean Engineering', 'Aviation Systems', 'Captain', 'US Navy (Retired)', 4, 1167, 0, Decimal('0.0'), 'STS-91 (Discovery), STS-99 (Endeavor), STS-123 (Endeavor), STS-108 (Endeavor)', '', ''),
#  ('Don L. Lind', 1966, 5, 'Retired', '1930-05-18', 'Midvale, UT', 'Male', 'University of Utah; University of California-Berkley', 'Physics', 'Nuclear Physics', 'Captain', 'US Navy (Retired)', 1, 168, 0, Decimal('0.0'), 'STS 51-B (Challenger)', '', ''),
#  ('Donald A. Thomas', 1990, 13, 'Retired', '1955-05-06', 'Cleveland, OH', 'Male', 'Case Western Reserve University; Cornell University', 'Physics', 'Materials Science', 'Captain', 'US Navy (Retired)', 4, 1040, 0, Decimal('0.0'), 'STS-65 (Columbia), STS-70 (Discovery), STS-83 (Columbia), STS-94 (Columbia)', '', ''),
#  ('Donald E. Williams', 1978, 8, 'Retired', '1958-02-13', 'Lafayette, IN', 'Male', 'Purdue University', 'Mechanical Engineering', 'Materials Science', 'Captain', 'US Navy (Retired)', 2, 287, 0, Decimal('0.0'), 'STS 51-D (Discovery), STS-34 (Atlantis)', '', ''),
#  ('Donald H. Peterson', 1969, 7, 'Retired', '1933-10-22', 'Winona, MS', 'Male', 'US Military Academy; US Air Force Institute of Technology', 'Mechanical Engineering', 'Nuclear Engineering', 'Colonel', 'US Air Force (Retired)', 1, 120, 1, Decimal('4.0'), 'STS-6 (Challenger)', '', ''),
#  ('Donald K. Slayton', 1959, 1, 'Deceased', '1924-03-01', 'Sparta, WI', 'Male', 'University of Minnesota', 'Aeronautical Engineering', 'Nuclear Engineering', 'Major', 'US Air Force Reserves', 1, 217, 0, Decimal('0.0'), 'Apollo-Soyuz Test Project', '1993-06-13', 'Natural causes'),
#  ('Donald L. Holmquest', 1967, 6, 'Retired', '1939-04-07', 'Dallas, TX', 'Male', 'Southern Methodist University; Baylor University; University of Houston', 'Electrical Engineering', 'Physiology; Medicine; Law', 'Major', 'US Air Force Reserves', 0, 0, 0, Decimal('0.0'), 'Apollo-Soyuz Test Project', '', ''),
#  ('Donald R. McMonagle', 1987, 12, 'Retired', '1952-05-14', 'Flint, MI', 'Male', 'US Air Force Academy; California State University-Fresno', 'Astronautical Engineering', 'Mechanical  Engineering', 'Colonel', 'US Air Force (Retired)', 3, 605, 0, Decimal('0.0'), 'STS-39 (Discovery), STS-54 (Endeavor), STS-66 (Atlantis)', '', ''),
#  ('Donald R. Pettit', 1996, 16, 'Active', '1955-04-20', 'Silverton, OR', 'Male', 'Oregon State University; University of Arizona', 'Chemical Engineering', 'Chemical Engineering', 'Colonel', 'US Air Force (Retired)', 3, 8872, 2, Decimal('13.0'), 'ISS-6 (Soyuz), STS-126 (Endeavor), ISS-30/31 (Soyuz)', '', ''),
#  ('Donn F. Eisele', 1963, 3, 'Deceased', '1930-05-23', 'Columbus, OH', 'Male', 'US Naval Academy; US Air Force Institute of Technology', 'Astronautics', 'Astronautics', 'Colonel', 'US Air Force (Retired)', 1, 260, 0, Decimal('0.0'), 'Apollo 7', '1987-12-02', 'Natural causes'),
#  ('Dorothy M. Metcalf-Lindenberger', 2004, 19, 'Active', '1975-05-02', 'Colorado Springs, CO', 'Female', 'Whitman College', 'Geology', 'Astronautics', 'Colonel', 'US Air Force (Retired)', 1, 362, 0, Decimal('0.0'), 'STS-131 (Discovery)', '', ''),
#  ('Douglas G. Hurley', 2000, 18, 'Active', '1966-10-21', 'Endicott, NY', 'Male', 'Tulane University', 'Civil Engineering', 'Astronautics', 'Colonel', 'US Marine Corps', 2, 683, 0, Decimal('0.0'), 'STS-127 (Endeavor), STS-135 (Atlantis)', '', ''),
#  ('Douglas H. Wheelock', 1998, 17, 'Active', '1960-05-05', 'Binghamton, NY', 'Male', 'US Military Academy; Georgia Institute of Technology', 'Applied Science & Engineering', 'Aerospace Engineering', 'Colonel', 'US Army', 2, 4281, 6, Decimal('43.0'), 'STS-120 (Discovery), ISS-24/25 (Soyuz)', '', ''),
#  ('Duane E. Graveline', 1965, 4, 'Retired', '1931-03-02', 'Newport, VT', 'Male', 'University of Vermont; Johns Hopkins University', 'Applied Science & Engineering', 'Public Health; Medicine', 'Colonel', 'US Army', 0, 0, 0, Decimal('0.0'), 'STS-120 (Discovery), ISS-24/25 (Soyuz)', '', ''),
#  ('Duane G. Carey', 1996, 16, 'Retired', '1957-04-30', 'St. Paul, MN', 'Male', 'University of Minnesota-Minneapolis', 'Aerospace Engineering & Mechanics', 'Aerospace Engineering', 'Lieutenant Colonel', 'US Air Force (Retired)', 1, 262, 0, Decimal('0.0'), 'STS-109 (Columbia)', '', ''),
#  ('E. Michael Fincke', 1996, 16, 'Active', '1967-03-14', 'Pittsburgh, PA', 'Male', 'MIT; Stanford University; University of Houston-Clear Lake', 'Aeronautics & Astronautics; Earth, Atmospheric & Planetary Sciences', 'Aeronautics & Astronautics; Physical Sciences', 'Colonel', 'US Air Force', 3, 9159, 9, Decimal('48.0'), 'ISS-09 (Soyuz), ISS-18 (Soyuz), STS-134 (Endeavor)', '', ''),
#  ('Edgar D. Mitchell', 1966, 5, 'Retired', '1930-09-17', 'Hereford, TX', 'Male', 'Carnegie-Mellon University; US Naval Postgraduate School; MIT', 'Industrial Management', 'Aeronautical Engineering; Aeronautics & Astronautics', 'Captain', 'US Navy (Retired)', 1, 216, 2, Decimal('9.0'), 'Apollo 14', '', ''),
#  ('Edward G. Gibson', 1965, 4, 'Retired', '1936-11-08', 'Buffalo, NY', 'Male', 'University of Rochester; California Institute of Technology', 'Engineering', 'Engineering', 'Captain', 'US Navy (Retired)', 1, 2017, 3, Decimal('15.0'), 'Skylab 4', '', ''),
#  ('Edward G. Givens Jr.', 1966, 5, 'Deceased', '1930-01-05', 'Quanah, TX', 'Male', 'US Naval Academy', 'Naval Sciences', 'Engineering', 'Major', 'US Air Force', 0, 0, 0, Decimal('0.0'), 'Skylab 4', '1967-06-06', 'Automobile accident '),
#  ('Edward H. White II', 1962, 2, 'Deceased', '1930-11-14', 'San Antonio, TX', 'Male', 'US Military Academy; University of Michigan', 'Naval Sciences', 'Aeronautical Engineering', 'Lieutenant Colonel', 'US Air Force', 2, 97, 1, Decimal('0.5'), 'Gemini 4, Apollo 1', '1967-01-27', 'Apollo 1'),
#  ('Edward T. Lu', 1995, 15, 'Retired', '1963-07-01', 'Springfield, MA', 'Male', 'Cornell University; Stanford University', 'Electrical Engineering', 'Applied Physics', 'Lieutenant Colonel', 'US Air Force', 3, 4962, 1, Decimal('6.0'), 'STS-84 (Atlantis), STS-106 (Atlantis), ISS-07 (Soyuz)', '', ''),
#  ('Eileen M. Collins', 1990, 13, 'Retired', '1959-11-19', 'Elmira, NY', 'Female', 'Syracuse University; Stanford University; Webster University', 'Mathematics & Economics', 'Operations Research; Space Systems Management', 'Colonel', 'US Air Force (Retired)', 4, 890, 0, Decimal('0.0'), 'STS-63 (Discovery), STS-84 (Atlantis), STS-114 (Columbia), STS-93 (Discovery)', '', ''),
#  ('Ellen Ochoa', 1990, 13, 'Management', '1958-05-10', 'Los Angeles, CA', 'Female', 'San Diego State University; Stanford University', 'Physics', 'Electrical Engineering', 'Colonel', 'US Air Force (Retired)', 4, 979, 0, Decimal('0.0'), 'STS-56 (Discovery), STS-66 (Atlantis), STS-96 (Discovery), STS-110 (Atlantis)', '', ''),
#  ('Ellen S. Baker', 1984, 10, 'Retired', '1953-04-27', 'Fayettesville, NC', 'Female', 'State University of New York-Buffalo; Cornell University; University of Texas', 'Geology', 'Medicine; Public Health', 'Colonel', 'US Air Force (Retired)', 3, 686, 0, Decimal('0.0'), 'STS-34 (Atlantis), STS-50 (Columbia), STS-71 (Atlantis)', '', ''),
#  ('Elliot M. See Jr.', 1962, 2, 'Deceased', '1927-07-23', 'Dallas, TX', 'Male', 'US Merchant Marine Academy; University of California-Los Angeles', 'Geology', 'Engineering', 'Colonel', 'US Air Force (Retired)', 0, 0, 0, Decimal('0.0'), 'STS-34 (Atlantis), STS-50 (Columbia), STS-71 (Atlantis)', '1966-02-28', 'T-38 jet aircraft'),
#  ('Ellison S. Onizuka', 1978, 8, 'Deceased', '1946-06-24', 'Kealakekua, HI', 'Male', 'University of Colorado', 'Aerospace Engineering', 'Aerospace Engineering', 'Lieutenant Colonel', 'US Air Force', 2, 73, 0, Decimal('0.0'), 'STS 51-C (Discovery), STS 51-L (Challenger)', '1986-01-28', 'STS 51-L (Challenger)'),
#  ('Eric A. Boe', 2000, 18, 'Active', '1964-10-01', 'Miami, FL', 'Male', 'US Air Force Academy; Georgia Institute of Technology', 'Aeronautical Engineering', 'Electrical Engineering', 'Colonel', 'US Air Force', 2, 687, 0, Decimal('0.0'), 'STS-126 (Endeavor), STS-133 (Discovery)', '', ''),
#  ('Eugene A. Cernan', 1963, 3, 'Deceased', '1934-03-14', 'Chicago, IL', 'Male', 'Purdue University; US Naval Postgraduate School', 'Electrical Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 3, 566, 4, Decimal('24.0'), 'Gemini 9, Apollo 10, Apollo 17', '2017-01-16', 'Natural causes'),
#  ('F. Andrew Gaffney', 1963, 3, 'Retired', '1946-06-09', 'Carlsbad, NM', 'Male', 'University of California-Berkeley; University of New Mexico', 'Psychology', 'Medicine', 'Captain', 'US Navy (Retired)', 1, 218, 0, Decimal('0.0'), 'STS-40 (Columbia)', '', ''),
#  ('F. Curtis Michel', 1965, 4, 'Retired', '1934-06-05', 'LaCrosse, WI', 'Male', 'California Institute of Technology', 'Physics', 'Physics', 'Captain', 'US Navy (Retired)', 0, 0, 0, Decimal('0.0'), 'STS-40 (Columbia)', '', ''),
#  ('Francis R. Scobee', 1978, 8, 'Deceased', '1939-05-19', 'Cle Elum, WA', 'Male', 'University of Arizona', 'Aerospace Engineering', 'Engineering Management', 'Major', 'US Air Force (Retired)', 2, 167, 0, Decimal('0.0'), 'STS 41-C (Challenger), STS 51-L (Challenger)', '1986-01-28', 'STS 51-L (Challenger)'),
#  ('Frank Borman', 1962, 2, 'Retired', '1928-03-14', 'Gary, IN', 'Male', 'US Military Academy; California Institute of Technology', 'Aerospace Engineering', 'Aeronautical Engineering', 'Colonel', 'US Air Force (Retired)', 2, 477, 0, Decimal('0.0'), 'Gemini 7, Apollo 8', '', ''),
#  ('Frank L. Culbertson Jr.', 1984, 10, 'Retired', '1949-05-15', 'Charleston, SC', 'Male', 'US Naval Academy', 'Aerospace Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 3, 3446, 1, Decimal('5.0'), 'STS-38 (Atlantis), STS-51 (Discovery), STS-105/108 (Discovery/Endeavor)', '', ''),
#  ('Franklin R. Chang-Diaz', 1980, 9, 'Retired', '1950-04-05', 'San Jose, Costa Rica', 'Male', 'University of Connecticut; MIT', 'Mechanical Engineering', 'Applied Plasma Physics', 'Captain', 'US Navy (Retired)', 7, 1602, 3, Decimal('19.0'), 'STS 61-C (Columbia), STS-34 (Atlantis), STS-46 (Atlantis), STS-60 (Discovery), STS-75 (Columbia), STS-91 (Discovery), STS-111 (Endeavor)', '', ''),
#  ('Fred W. Haise Jr.', 1966, 5, 'Retired', '1933-11-14', 'Biloxi, MS', 'Male', 'University of Oklahoma', 'Aeronautical Engineering', 'Applied Plasma Physics', 'Captain', 'US Navy (Retired)', 1, 142, 0, Decimal('0.0'), 'Apollo 13', '', ''),
#  ('Fred W. Leslie', 1966, 5, 'Retired', '1951-12-19', 'Ancon, Panama', 'Male', 'University of Texas; University of Oklahoma', 'Engineering Science', 'Meteorology', 'Captain', 'US Navy (Retired)', 1, 381, 0, Decimal('0.0'), 'STS-73 (Columbia)', '', ''),
#  ('Frederick D. Gregory', 1978, 8, 'Retired', '1941-01-07', 'Washington, DC', 'Male', 'US Air Force Academy; George Washington University', 'Engineering Science', 'Information Systems', 'Colonel', 'US Air Force (Retired)', 3, 455, 0, Decimal('0.0'), 'STS 51-B (Challenger), STS-33 (Discovery), STS-44 (Atlantis)', '', ''),
#  ('Frederick H. Hauck', 1978, 8, 'Retired', '1941-04-11', 'Long Beach, CA', 'Male', 'Tufts University; MIT', 'Physics', 'Nuclear Engineering', 'Captain', 'US Navy (Retired)', 3, 435, 0, Decimal('0.0'), 'STS-7 (Challenger), STS 51-A (Discovery), STS-26 (Discovery)', '', ''),
#  ('Frederick W. Sturckow', 1995, 15, 'Retired', '1961-08-11', 'La Mesa, CA', 'Male', 'California Polytechnic State University', 'Mechanical Engineering', 'Nuclear Engineering', 'Colonel', 'US Marine Corps (Retired)', 4, 1233, 0, Decimal('0.0'), 'STS-88 (Endeavor), STS-105 (Discovery), STS-117 (Atlantis), STS-128 (Discovery)', '', ''),
#  ('G. David Low', 1984, 10, 'Deceased', '1956-02-19', 'Cleveland, OH', 'Male', 'Washington & Lee University; Cornell University; Stanford University', 'Physics & Engineering', 'Mechanical Engineering; Aeronautics & Astronautics', 'Colonel', 'US Marine Corps (Retired)', 3, 714, 1, Decimal('6.0'), 'STS-32 (Columbia), STS-43 (Atlantis), STS-57 (Endeavor)', '2008-03-15', 'Natural causes'),
#  ('G. Reid Wiseman', 2009, 20, 'Active', '1975-11-11', 'Baltimore, MD', 'Male', 'Rensselaer Polytechnic Institute; Johns Hopkins University', 'Computer & Systems Engineering', 'Systems Engineering', 'Commander', 'US Navy', 1, 3968, 2, Decimal('13.0'), 'ISS-40/41 (Soyuz)', '', ''),
#  ('Garrett E. Reisman', 1998, 17, 'Retired', '1968-02-10', 'Morristown, NJ', 'Male', 'University of Pennsylvania; California Institute of Technology', 'Economics', 'Mechanical  Engineering', 'Commander', 'US Navy', 2, 2571, 3, Decimal('21.0'), 'STS-123/124 (Endeavor/Discovery), STS-132 (Atlantis)', '', ''),
#  ('Gary E. Payton', 1998, 17, 'Retired', '1948-06-20', 'Rock Island, IL', 'Male', 'US Air Force Academy; Purdue University', 'Astronautical Engineering', 'Astronautical & Aeronautical Engineering', 'Major', 'US Air Force', 1, 73, 0, Decimal('0.0'), 'STS 51-C (Discovery)', '', ''),
#  ('George D. Nelson', 1978, 8, 'Retired', '1950-07-13', 'Charles City, IA', 'Male', 'Harvey Mudd College; University of Washington', 'Physics', 'Astronomy', 'Major', 'US Air Force', 3, 411, 2, Decimal('10.0'), 'STS 41-C (Challenger), STS 61-C (Columbia), STS-26 (Discovery)', '', ''),
#  ('George D. Zamka', 1998, 17, 'Retired', '1962-06-29', 'Jersey City, NJ', 'Male', 'US Naval Academy; Florida Institute of Technology', 'Mathematics', 'Engineering Management', 'Colonel', 'US Marine Corps (Retired)', 2, 692, 0, Decimal('0.0'), 'STS-120 (Discovery), STS-130 (Endeavor)', '', ''),
#  ('Gerald P. Carr', 1966, 5, 'Retired', '1932-08-22', 'Denver, CO', 'Male', 'University of Southern California; US Naval Postgraduate School; Princeton University', 'Mechanical Engineering', 'Aeronautical Engineering', 'Colonel', 'US Marine Corps (Retired)', 1, 2017, 3, Decimal('16.0'), 'Skylab 4', '', ''),
#  ('Gregory B. Jarvis', 1966, 5, 'Deceased', '1944-08-24', 'Detroit, MI', 'Male', 'State University of New York at Buffalo; Northeastern University', 'Electrical Engineering', 'Electrical Engineering', 'Colonel', 'US Marine Corps (Retired)', 1, 0, 0, Decimal('0.0'), 'STS 51-L (Challenger)', '1986-01-28', 'STS 51-L (Challenger)'),
#  ('Gregory C. Johnson', 1998, 17, 'Management', '1954-07-30', 'Seattle, WA', 'Male', 'University of Washington', 'Aerospace Engineering', 'Electrical Engineering', 'Captain', 'US Navy (Retired)', 1, 309, 0, Decimal('0.0'), 'STS-125 (Atlantis)', '', ''),
#  ('Gregory E. Chamitoff', 1998, 17, 'Active', '1962-08-06', 'Montreal, Canada', 'Male', 'California Polytechnic State University; California Institute of Technology; MIT', 'Electrical Engineering', 'Aeronautical Engineering; Aeronautics & Astronautics', 'Captain', 'US Navy (Retired)', 2, 4770, 2, Decimal('13.0'), 'STS-124/126 (Discovery/Endeavor), STS-134 (Endeavor)', '', ''),
#  ('Gregory H. Johnson', 1998, 17, 'Active', '1962-05-12', 'London, England', 'Male', 'US Air Force Academy; Columbia University; University of Texas', 'Aeronautical Engineering', 'Flight Structures Engineering; Business Administration', 'Colonel', 'US Air Force (Retired)', 2, 755, 0, Decimal('0.0'), 'STS-123 (Endeavor), STS-134 (Endeavor)', '', ''),
#  ('Gregory J. Harbaugh', 1987, 12, 'Retired', '1956-04-15', 'Cleveland, OH', 'Male', 'Purdue University; University of Houston-Clear Lake', 'Aeronautical & Astronautical Engineering', 'Physical Science', 'Colonel', 'US Air Force (Retired)', 4, 817, 3, Decimal('18.0'), 'STS-39 (Discovery), STS-54 (Endeavor), STS-71 (Atlantis), STS-82 (Discovery)', '', ''),
#  ('Gregory T. Linteris', 1987, 12, 'Retired', '1957-10-04', 'Demarest, NJ', 'Male', 'Princeton University; Stanford University', 'Chemical Engineering', 'Mechanical Engineering; Mechanical & Aerospace Engineering', 'Colonel', 'US Air Force (Retired)', 2, 471, 0, Decimal('0.0'), 'STS-83 (Columbia), STS-94 (Columbia)', '', ''),
#  ('Guion S. Bluford Jr.', 1978, 8, 'Retired', '1942-11-22', 'Philadelphia, PA', 'Male', 'Pennsylvania State University; Air Force Institute of Technology; University of Houston-Clear Lake', 'Aerospace Engineering', 'Aerospace Engineering; Business Administration', 'Colonel', 'US Air Force (Retired)', 4, 689, 0, Decimal('0.0'), 'STS-8 (Challenger), STS 61-A (Challenger), STS-39 (Discovery), STS-53 (Discovery)', '', ''),
#  ('Guy S. Gardner', 1980, 9, 'Retired', '1948-01-06', 'Alta Vista, VA', 'Male', 'US Air Force Academy; Purdue University', 'Engineering Sciences; Astronautics & Mathematics', 'Astronautics', 'Colonel', 'US Air Force (Retired)', 2, 320, 0, Decimal('0.0'), 'STS-27 (Atlantis), STS-35 (Columbia)', '', ''),
#  ('Harrison H. Schmitt', 1965, 4, 'Retired', '1935-07-03', 'Santa Rita, NM', 'Male', 'California Institute of Technology; Harvard University', 'Geology', 'Geology', 'Colonel', 'US Air Force (Retired)', 1, 301, 3, Decimal('22.0'), 'Apollo 17', '', ''),
#  ('Heidemarie M. Stefanyshyn-Piper', 1996, 16, 'Retired', '1963-02-07', 'St. Paul, MN', 'Female', 'MIT', 'Mechanical Engineering', 'Geology', 'Captain', 'US Navy', 2, 663, 2, Decimal('33.0'), 'STS-115 (Atlantis), STS-126 (Endeavor)', '', ''),
#  ('Henry W. Hartsfield Jr.', 1969, 7, 'Retired', '1933-11-21', 'Birmingham, AL', 'Male', 'Auburn University; University of Tennessee', 'Physics', 'Engineering Science', 'Colonel', 'US Air Force (Retired)', 3, 482, 0, Decimal('0.0'), 'STS-4 (Columbia), STS 41-D (Discovery), STS 61-A (Challenger)', '', ''),
#  ('Jack D. Fischer', 2009, 20, 'Active', '1974-01-23', 'Louisville, CO', 'Male', 'US Air Force Academy; MIT', 'Astronautical Engineering', 'Aeronautics & Astronautics', 'Colonel', 'US Air Force (Retired)', 0, 0, 0, Decimal('0.0'), 'STS 51-I (Discovery), STS-26 (Discovery), STS-35 (Columbia)', '', ''),
#  ('Jack R. Lousma', 1966, 5, 'Retired', '1936-02-29', 'Grand Rapids, MI', 'Male', 'University of Michigan; US Naval Postgraduate School', 'Aeronautical Engineering', 'Aeronautical Engineering', 'Colonel', 'US Marine Corps (Retired)', 2, 1619, 2, Decimal('11.0'), 'Skylab 3, STS-3 (Columbia)', '', ''),
#  ('Jake Garn', 1966, 5, 'Retired', '1932-10-12', 'Richfield. UT', 'Male', 'University of Utah', 'Business Finance', 'Aeronautical Engineering', 'Colonel', 'US Marine Corps (Retired)', 1, 167, 0, Decimal('0.0'), 'STS 51-D (Discovery)', '', ''),
#  ('James A. Lovell Jr.', 1962, 2, 'Retired', '1928-03-25', 'Cleveland, OH', 'Male', 'US Naval Academy', 'Business Finance', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 4, 715, 0, Decimal('0.0'), 'Gemini 7, Gemini 12, Apollo 8, Apollo 13', '', ''),
#  ('James A. McDivitt', 1984, 2, 'Retired', '1929-06-10', 'Chicago, IL', 'Male', 'University of Michigan', 'Astronautical Engineering', 'Aeronautical Engineering', 'Brigadier General', 'US Air Force (Retired)', 2, 338, 0, Decimal('0.0'), 'Gemini 4, Apollo 9', '', ''),
#  ('James A. Pawelczyk', 1984, 2, 'Retired', '1960-09-20', 'Buffalo, NY', 'Male', 'University of Rochester; Pennsylvania State University; University of North Texas', 'Biology & Psychology', 'Physiology; Biology', 'Brigadier General', 'US Air Force (Retired)', 1, 381, 0, Decimal('0.0'), 'STS-90 (Columbia)', '', ''),
#  ('James B. Irwin', 1966, 5, 'Deceased', '1930-03-17', 'Pittsburgh, PA', 'Male', 'US Naval Academy; University of Michigan', 'Naval Sciences', 'Aeronautical Engineering', 'Colonel', 'US Air Force (Retired)', 1, 295, 3, Decimal('20.0'), 'Apollo 15', '1991-08-08', 'Natural causes'),
#  ('James C. Adamson', 1984, 10, 'Retired', '1946-03-03', 'Warsaw, NY', 'Male', 'US Military Academy; Princeton University', 'Engineering', 'Aerospace Engineering', 'Colonel', 'US Army (Retired)', 2, 334, 0, Decimal('0.0'), 'STS-28 (Columbia), STS-43 (Atlantis)', '', ''),
#  ('James D. Halsell Jr.', 1990, 13, 'Retired', '1956-09-29', 'Monroe, LA', 'Male', 'US Air Force Academy; Troy State University; US Air Force Institute of Technology', 'Engineering', 'Business Management; Space Operations', 'Colonel', 'US Air Force (Retired)', 5, 1258, 0, Decimal('0.0'), 'STS-65 (Columbia), STS-74 (Atlantis), STS-83 (Columbia), STS-94 (Columbia), STS-101 (Atlantis)', '', ''),
#  ('James D. van Hoften', 1978, 8, 'Retired', '1944-06-11', 'Fresno, CA', 'Male', 'University of California-Berkeley; Colorado State University', 'Civil Engineering', 'Hydraulic Engineering; Fluid Mechanics', 'Colonel', 'US Air Force (Retired)', 2, 338, 4, Decimal('22.0'), 'STS 41-C (Challenger), STS 51-I (Discovery)', '', ''),
#  ('James D. Wetherbee', 1984, 10, 'Retired', '1952-11-27', 'Flushing, NY', 'Male', 'University of Notre Dame', 'Aerospace Engineering', 'Hydraulic Engineering; Fluid Mechanics', 'Captain', 'US Navy (Retired)', 6, 1594, 0, Decimal('0.0'), 'STS-32 (Columbia), STS-52 (Columbia), STS-63 (Discovery), STS-86 (Atlantis), STS-102 (Discovery), STS-113 (Endeavor)', '', ''),
#  ('James F. Buchli', 1978, 8, 'Retired', '1945-06-20', 'New Rockford, ND', 'Male', 'US Naval Academy; University of West Florida', 'Aeronautical Engineering', 'Aeronautical Engineering Systems', 'Colonel', 'US Marine Corps (Retired)', 4, 490, 0, Decimal('0.0'), 'STS 51-C (Discovery), STS 61-A (Challenger), STS-29 (Discovery), STS-48 (Discovery', '', ''),
#  ('James F. Reilly II', 1995, 15, 'Retired', '1954-03-18', 'Mountain Home Air Force Base, ID', 'Male', 'University of Texas-Dallas', 'Geosciences', 'Geosciences', 'Colonel', 'US Marine Corps (Retired)', 3, 854, 5, Decimal('31.0'), 'STS-89 (Endeavor), STS-104 (Atlantis), STS-117 (Atlantis)', '', ''),
#  ('James H. Newman', 1990, 13, 'Retired', '1956-10-16', 'San Diego, CA', 'Male', 'Dartmouth College; Rice University', 'Physics', 'Physics', 'Colonel', 'US Marine Corps (Retired)', 4, 1042, 6, Decimal('43.0'), 'STS-51 (Discovery), STS-69 (Endeavor), STS-88 (Endeavor), STS- 109 (Columbia)', '', ''),
#  ('James M. Kelly', 1996, 16, 'Management', '1964-05-14', 'Burlington, IA', 'Male', 'US Air Force Academy; University of Alabama', 'Astronautical Engineering', 'Aerospace Engineering', 'Colonel', 'US Air Force (Retired)', 2, 641, 0, Decimal('0.0'), 'STS-102 (Discovery), STS-114 (Discovery)', '', ''),
#  ('James P. Bagian', 1980, 9, 'Retired', '1952-02-22', 'Philadelphia, PA', 'Male', 'Drexel University; Thomas Jefferson University', 'Mechanical Engineering', 'Medicine', 'Colonel', 'US Air Force (Retired)', 2, 337, 0, Decimal('0.0'), 'STS-29 (Discovery), STS-40 (Columbia)', '', ''),
#  ('James P. Dutton Jr.', 2004, 19, 'Management', '1968-11-20', 'Eugene, OR', 'Male', 'US Air Force Academy; University of Washington', 'Astronautical Engineering', 'Aeronautics & Astronautics', 'Colonel', 'US Air Force', 1, 362, 0, Decimal('0.0'), 'STS-131 (Discovery)', '', ''),
#  ('James S. Voss', 1987, 12, 'Retired', '1949-03-03', 'Cordova, AL', 'Male', 'Auburn University; University of Colorado', 'Aerospace Engineering', 'Aerospace Engineering Sciences', 'Colonel', 'US Army (Retired)', 5, 4853, 4, Decimal('22.0'), 'STS-44 (Atlantis), STS-53 (Discovery), STS-69 (Endeavor), STS-101 (Atlantis), STS-102/105 (Discovery)', '', ''),
#  ('Janet L. Kavandi', 1995, 15, 'Management', '1959-07-17', 'Springfield, MO', 'Female', 'Missouri Southern State College; University of Missouri; University of Washington', 'Chemistry', 'Chemistry', 'Colonel', 'US Army (Retired)', 3, 812, 0, Decimal('0.0'), 'STS-91 (Discovery), STS-99 (Endeavor), STS-104 (Atlantis)', '', ''),
#  ('Janice E. Voss', 1990, 13, 'Deceased', '1956-10-08', 'South Bend, IN', 'Female', 'Purdue University; MIT', 'Engineering Science', 'Electrical Engineering; Aeronautics & Astronautics', 'Colonel', 'US Army (Retired)', 5, 1179, 0, Decimal('0.0'), 'STS-57 (Endeavor), STS-63 (Discovery), STS-83 (Columbia), STS-94 (Columbia), STS-99 (Endeavor)', '2012-02-06', 'Natural causes'),
#  ('Jay Clark Buckey', 1990, 13, 'Retired', '1956-06-06', 'New York, NY', 'Male', 'Cornell University', 'Electrical Engineering', 'Medicine', 'Colonel', 'US Army (Retired)', 1, 381, 0, Decimal('0.0'), 'STS-90 (Columbia)', '', ''),
#  ('Jeanette J. Epps', 2009, 20, 'Active', '1970-11-03', 'Syracuse, NY', 'Female', 'LeMoyne College; University of Maryland', 'Physics', 'Aerospace Engineering', 'Colonel', 'US Army (Retired)', 0, 0, 0, Decimal('0.0'), 'STS-90 (Columbia)', '', ''),
#  ('Jeffrey A. Hoffman', 1978, 8, 'Retired', '1944-11-02', 'Brooklyn, NY', 'Male', 'Amherst College; Rice University; Harvard University', 'Astronomy', 'Materials Science; Astrophysics', 'Colonel', 'US Army (Retired)', 5, 1211, 4, Decimal('25.0'), 'STS 51-D (Discovery), STS-35 (Columbia), STS-46 (Atlantis), STS-61 (Endeavor), STS-75 (Columbia)', '', ''),
#  ('Jeffrey N. Williams', 1996, 16, 'Active', '1958-01-18', 'Superior, WI', 'Male', 'US Military Academy; US Naval Postgraduate School; US Naval War College', 'Applied Science & Engineering', 'Aeronautical Engineering; National Security & Strategic Studies', 'Colonel', 'US Army (Retired)', 4, 12818, 5, Decimal('32.0'), 'STS-101 (Atlantis), ISS-13 (Soyuz), ISS-21/22 (Soyuz), ISS-47/48 (Soyuz)', '', ''),
#  ('Jeffrey S. Ashby', 1995, 15, 'Retired', '1954-06-01', 'Dallas, TX', 'Male', 'University of Idaho; University of Tennessee', 'Mechanical Engineering', 'Aviation Systems', 'Captain', 'US Navy (Retired)', 3, 655, 0, Decimal('0.0'), 'STS-93 (Columbia), STS-100 (Endeavor), STS-112 (Atlantis)', '', ''),
#  ('Jerome Apt III', 1985, 11, 'Retired', '1949-04-18', 'Springfield, MA', 'Male', 'Harvard University; MIT', 'Physics', 'Physics', 'Captain', 'US Navy (Retired)', 4, 847, 2, Decimal('11.0'), 'STS-37 (Atlantis), STS-47 (Endeavor), STS-59 (Endeavor), STS-79 (Atlantis)', '', ''),
#  ('Jerry L. Ross', 1980, 9, 'Retired', '1948-01-20', 'Crown Point, IN', 'Male', 'Purdue University', 'Mechanical Engineering', 'Mechanical Engineering', 'Colonel', 'US Air Force (Retired)', 7, 1393, 9, Decimal('58.0'), 'ST 61-B (Atlantis), ST-27 (Atlantis), ST-37 (Atlantis), STS-55 (Columbia), STS-74 (Atlantis), STS-88 (Endeavor), STS-110 (Atlantis)', '', ''),
#  ('Jerry M. Linenger', 1992, 14, 'Retired', '1955-01-16', 'Mount Clemens, MI', 'Male', 'US Naval Academy; University of Southern California; University of North Carolina; Wayne State University', 'Bioscience', 'Systems Management; Public Health; Medicine; Epidemiology', 'Captain', 'US Navy (Retired)', 2, 3435, 1, Decimal('5.0'), 'STS-64 (Discovery), STS-81/84 (Atlantis)', '', ''),
#  ('Joan E. Higginbotham', 1996, 16, 'Retired', '1964-08-03', 'Chicago, IL', 'Female', 'Southern Illinois University-Carbondale; Florida Institute of Technology', 'Electrical Engineering', 'Business Management; Space Systems', 'Captain', 'US Navy (Retired)', 1, 308, 0, Decimal('0.0'), 'STS-116 (Discovery)', '', ''),
#  ('Joe F. Edwards Jr.', 1995, 15, 'Retired', '1958-02-03', 'Richmond, VA', 'Male', 'US Naval Academy; University of Tennessee-Knoxville', 'Aerospace Engineering', 'Aviation Systems', 'Commander', 'US Navy (Retired)', 1, 211, 0, Decimal('0.0'), 'STS-89 (Endeavor)', '', ''),
#  ('Joe H. Engle', 1966, 5, 'Retired', '1932-08-26', 'Dickinson, KS', 'Male', 'University of Kansas', 'Aeronautical Engineering', 'Aviation Systems', 'Major General', 'US Air Force (Retired)', 2, 224, 0, Decimal('0.0'), 'STS-2 (Columbia), STS 51-I (Discovery)', '', ''),
#  ('John A. Llewellyn', 1967, 6, 'Retired', '1933-04-22', 'Cardiff, Wales', 'Male', 'University College at Cardiff', 'Chemistry', 'Chemistry', 'Major General', 'US Air Force (Retired)', 0, 0, 0, Decimal('0.0'), 'STS-2 (Columbia), STS 51-I (Discovery)', '', ''),
#  ('John B. Herrington', 1996, 16, 'Retired', '1958-09-14', 'Wetumka, OK', 'Male', 'University of Colorado; US Naval Postgraduate School', 'Applied Mathematics', 'Aeronautical Engineering', 'Commander', 'US Navy (Retired)', 1, 330, 3, Decimal('20.0'), 'STS-113 (Endeavor)', '', ''),
#  ('John D. Olivas', 1998, 17, 'Retired', '1966-05-25', 'North Hollywood, CA', 'Male', 'University of Texas-El Paso; University of Houston; Rice University', 'Mechanical Engineering', 'Mechanical  Engineering; Mechanical  Engineering & Materials Science', 'Commander', 'US Navy (Retired)', 2, 665, 5, Decimal('34.0'), 'STS-117 (Atlantis), STS-128 (Discovery)', '', ''),
#  ('John E. Blaha', 1980, 9, 'Retired', '1942-08-26', 'San Antonio, TX', 'Male', 'US Air Force Academy; Purdue University', 'Engineering Science', 'Astronautical Engineering', 'Colonel', 'US Air Force (Retired)', 5, 3861, 0, Decimal('0.0'), 'STS-29 (Discovery), STS-33 (Discovery), STS-43 (Atlantis), STS-58 (Columbia), STS-79/81 (Atlantis/Atlantis)', '', ''),
#  ('John H. Casper', 1984, 10, 'Management', '1943-07-09', 'Greenville, SC', 'Male', 'US Air Force Academy; Purdue University', 'Engineering Science', 'Astronautics', 'Colonel', 'US Air Force (Retired)', 4, 825, 0, Decimal('0.0'), 'STS-36 (Atlantis), STS-54 (Endeavor), STS-62 (Columbia), STS-77 (Endeavor)', '', ''),
#  ('John H. Glenn Jr.', 1959, 1, 'Deceased', '1921-07-18', 'Cambridge, OH', 'Male', 'Muskingum College', 'Engineering', 'Astronautics', 'Colonel', 'US Marine Corps (Retired)', 2, 218, 0, Decimal('0.0'), 'Mercury 6, STS-95 (Discovery)', '2016-12-08', 'Complications from surgery'),
#  ('John L. Phillips', 1996, 16, 'Retired', '1951-04-15', 'Ft. Belvoir, VA', 'Male', 'US Naval Academy; University of West Florida; University of California-Los Angeles', 'Mathematics; Russian', 'Aeronautical Systems; Geophysics & Space Physics', 'Captain', 'US Naval Reserves (Retired)', 3, 4880, 1, Decimal('5.0'), 'STS-100 (Endeavor), ISS-11 (Soyuz), STS-119 (Discovery)', '', ''),
# ...
#  ('Sherwood C. Spring', 1980, 9, 'Retired', '1944-09-23', 'Hartford, CT', 'Male', 'US Military Academy; University of Arizona', 'Engineering', 'Aerospace Engineering', 'Colonel', 'US Army (Retired)', 1, 165, 2, Decimal('12.0'), 'STS 61-B (Atlantis)', '', ''),
#  ('Sidney M. Gutierrez', 1984, 10, 'Retired', '1951-06-27', 'Albuquerque, NM', 'Male', 'US Air Force Academy; Webster College', 'Aeronautical Engineering', 'Business Management', 'Colonel', 'US Air Force (Retired)', 2, 488, 0, Decimal('0.0'), 'STS-40 (Columbia), STS-59 (Endeavor)', '', ''),
#  ('Stanley G. Love', 1998, 17, 'Management', '1965-06-08', 'San Diego, CA', 'Male', 'Harvey Mudd College; University of Washington', 'Physics', 'Astronomy', 'Colonel', 'US Air Force (Retired)', 1, 306, 2, Decimal('15.0'), 'STS-122 (Atlantis)', '', ''),
#  ('Stephanie D. Wilson', 1996, 16, 'Active', '1966-09-27', 'Boston, MA', 'Female', 'Harvard University; University of Texas', 'Engineering Science', 'Aerospace Engineering', 'Colonel', 'US Air Force (Retired)', 3, 1031, 0, Decimal('0.0'), 'STS-121 (Discovery), STS-120 (Discovery), STS-131 (Discovery)', '', ''),
#  ('Stephen G. Bowen', 2000, 18, 'Active', '1964-02-13', 'Cohasset, MA', 'Male', 'US Naval Academy; MIT', 'Electrical Engineering', 'Ocean Engineering', 'Captain', 'US Navy', 3, 970, 7, Decimal('47.0'), 'STS-126 (Endeavor), STS-132 (Atlantis), STS-133 (Discovery)', '', ''),
#  ('Stephen K. Robinson', 1995, 15, 'Retired', '1955-10-26', 'Sacramento, CA', 'Male', 'University of California-Davis; Stanford University', 'Mechanical & Aeronautical Engineering', 'Mechanical  Engineering', 'Captain', 'US Navy', 4, 1162, 3, Decimal('20.0'), 'STS-85 (Discovery), STS-95 (Discovery), STS-114 (Discovery), STS-130 (Endeavor)', '', ''),
#  ('Stephen N. Frick', 1996, 16, 'Management', '1961-09-30', 'Pittsburgh, PA', 'Male', 'US Naval Academy; US Naval Postgraduate School', 'Aerospace Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 2, 566, 0, Decimal('0.0'), 'STS-110 (Atlantis), STS-122 (Atlantis)', '', ''),
#  ('Stephen S. Oswald', 1985, 11, 'Retired', '1951-06-30', 'Seattle, WA', 'Male', 'US Naval Academy', 'Aerospace Engineering', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 3, 814, 0, Decimal('0.0'), 'STS-42 (Discovery), STS-56 (Discovery), STS-67 (Endeavor)', '', ''),
#  ('Steven A. Hawley', 1978, 8, 'Retired', '1951-12-12', 'Ottawa, KS', 'Male', 'University of Kansas; University of California', 'Physics & Astronomy', 'Astronomy & Astrophysics', 'Captain', 'US Navy (Retired)', 5, 770, 0, Decimal('0.0'), 'STS 41-D (Discovery), STS 61-C (Columbia), STS-31 (Discovery), STS-82 (Discovery), STS-93 (Columbia)', '', ''),
#  ('Steven L. Smith', 1992, 14, 'Management', '1958-12-30', 'Phoenix, AZ', 'Male', 'Stanford University', 'Electrical Engineering', 'Electrical Engineering', 'Captain', 'US Navy (Retired)', 4, 960, 7, Decimal('49.0'), 'STS-68 (Endeavor), STS-82 (Discovery), STS-103 (Discovery), STS-110 (Atlantis)', '', ''),
#  ('Steven R. Nagel', 1978, 8, 'Retired', '1946-10-27', 'Canton, IL', 'Male', 'University of Illinois; California State University-Fresno', 'Aerospace Engineering', 'Mechanical  Engineering', 'Colonel', 'US Air Force (Retired)', 4, 721, 0, Decimal('0.0'), 'STS 51-G (Discovery), STS 61-A (Challenger), STS-37 (Atlantis), STS-55 (Columbia)', '', ''),
#  ('Steven R. Swanson', 1998, 17, 'Active', '1960-12-03', 'Syracuse, NY', 'Male', 'University of Colorado; Florida Atlantic University; Texas A&M University', 'Engineering Physics', 'Computer Systems; Computer Science', 'Colonel', 'US Air Force (Retired)', 3, 4700, 5, Decimal('28.0'), 'STS-117 (Atlantis), STS-119 (Discovery), ISS-39/40 (Soyuz)', '', ''),
#  ('Steven W. Lindsey', 1995, 15, 'Retired', '1960-08-24', 'Arcadia, CA', 'Male', 'US Air Force Academy; US Air Force Institute of Technology', 'Engineering Science', 'Aeronautical Engineering', 'Colonel', 'US Air Force (Retired)', 5, 1510, 0, Decimal('0.0'), 'STS-87 (Columbia), STS-95 (Discovery), STS-104 (Atlantis), STS-121 (Discovery), STS-133 (Discovery)', '', ''),
#  ('Story Musgrave', 1967, 6, 'Retired', '1935-08-19', 'Boston, MA', 'Male', 'Syracuse University; Marietta College; University of California-Los Angeles; University of Kentucky; University of Houston; Columbia University', 'Mathematics & Statistics; Chemistry', 'Business Administration; Physiology; Literature; Medicine', 'Colonel', 'US Air Force (Retired)', 6, 1281, 4, Decimal('26.0'), 'STS-6 (Challenger), STS 51-F (Challenger), STS-33 (Discovery), STS-44 (Atlantis), STS-61 (Endeavor), STS-80 (Columbia)', '', ''),
#  ('Stuart A. Roosa', 1966, 5, 'Deceased', '1933-08-16', 'Durango, CO', 'Male', 'University of Colorado', 'Aeronautical Engineering', 'Business Administration; Physiology; Literature; Medicine', 'Colonel', 'US Air Force (Retired)', 1, 216, 0, Decimal('0.0'), 'Apollo 14', '1994-12-12', 'Natural causes'),
#  ('Sunita L. Williams', 1998, 17, 'Active', '1965-09-19', 'Euclid, OH', 'Female', 'US Naval Academy; Florida Institute of Technology', 'Physical Science', 'Engineering Management', 'Captain', 'US Navy', 2, 7721, 7, Decimal('50.0'), 'STS-116/117 (Discovery/Atlantis), ISS-32/33 (Soyuz)', '', ''),
#  ('Susan J. Helms', 1990, 13, 'Retired', '1958-02-26', 'Charlotte, NC', 'Female', 'US Air Force Academy; Stanford University', 'Aeronautical Engineering', 'Aeronautics & Astronautics', 'Lieutenant General', 'US Air Force', 5, 5063, 1, Decimal('9.0'), 'STS-54 (Endeavor), STS-64 (Discovery), STS-78 (Columbia), STS-101 (Atlantis), STS-102/105 (Discovery)', '', ''),
#  ('Susan L. Kilrain (Still)', 1995, 15, 'Retired', '1961-10-24', 'Augusta, GA', 'Female', 'Embry-Riddle University; Georgia Institute of Technology', 'Astronautical Engineering', 'Aerospace Engineering', 'Commander', 'US Navy (Retired)', 2, 472, 0, Decimal('0.0'), 'STS-83 (Columbia), STS-94 (Columbia)', '', ''),
#  ('Tamara E. Jernigan', 1985, 11, 'Retired', '1959-05-07', 'Chattanooga, TN', 'Female', 'Stanford University; University of California-Berkeley; Rice University', 'Physics', 'Engineering Science; Astronomy', 'Commander', 'US Navy (Retired)', 5, 1489, 1, Decimal('8.0'), 'STS-40 (Columbia), STS-52 (Columbia), STS-67 (Endeavor), STS-80 (Columbia), STS-98 (Discovery)', '', ''),
#  ('Taylor G. Wang', 1985, 11, 'Retired', '1940-06-16', 'Jiangxi, China', 'Male', 'University of California at Los Angeles', 'Physics', 'Physics', 'Commander', 'US Navy (Retired)', 1, 168, 0, Decimal('0.0'), 'STS 51-B (Challenger)', '', ''),
#  ('Terence T. Henricks', 1985, 11, 'Retired', '1952-07-05', 'Bryan, OH', 'Male', 'US Air Force Academy; Golden Gate University', 'Civil Engineering', 'Public Administration', 'Colonel', 'US Air Force (Retired)', 4, 1026, 0, Decimal('0.0'), 'STS-44 (Atlantis), STS-55 (Columbia), STS-70 (Discovery), STS-78 (Columbia)', '', ''),
#  ('Terrence W. Wilcutt', 1990, 13, 'Management', '1949-10-31', 'Russellville, KY', 'Male', 'Western Kentucky University', 'Mathematics', 'Public Administration', 'Colonel', 'US Air Force (Retired)', 4, 1008, 0, Decimal('0.0'), 'STS-68 (Endeavor), STS-79 (Atlantis), STS-89 (Endeavor), STS-106 (Atlantis)', '', ''),
#  ('Terry J. Hart', 1978, 8, 'Retired', '1946-10-27', 'Pittsburgh, PA', 'Male', 'Lehigh University; MIT; Rutgers University', 'Mechanical Engineering', 'Mechanical Engineering; Electrical Engineering', 'Colonel', 'US Air Force (Retired)', 1, 167, 0, Decimal('0.0'), 'STS 41-C (Challenger)', '', ''),
#  ('Terry W. Virts Jr.', 2000, 18, 'Active', '1967-12-01', 'Baltimore, MD', 'Male', 'US Air Force Academy; Embry-Riddle Aeronautical University', 'Mathematics', 'Aeronautics', 'Colonel', 'US Air Force', 2, 5122, 3, Decimal('18.0'), 'STS-130 (Endeavor), ISS-42/43 (Soyuz)', '', ''),
#  ('Theodore C. Freeman', 1963, 3, 'Deceased', '1930-02-18', 'Haversford, PA', 'Male', 'US Naval Academy; University of Michigan', 'Mathematics', 'Aeronautical Engineering', 'Captain', 'US Air Force', 0, 0, 0, Decimal('0.0'), 'STS-130 (Endeavor), ISS-42/43 (Soyuz)', '1964-10-31', 'T-38 jet aircraft'),
#  ('Thomas D. Akers', 1987, 12, 'Retired', '1951-05-20', 'St. Louis, MO', 'Male', 'University of Missouri-Rolla', 'Applied Mathematics', 'Applied Mathematics', 'Colonel', 'US Air Force (Retired)', 4, 814, 4, Decimal('29.0'), 'STS-41 (Discovery), STS-49 (Endeavor), STS-61 (Endeavor), STS-79 (Atlantis)', '', ''),
#  ('Thomas D. Jones', 1990, 13, 'Retired', '1955-01-22', 'Baltimore, MD', 'Male', 'US Air Force Academy; University of Arizona', 'Applied Mathematics', 'Planetary Science', 'Colonel', 'US Air Force (Retired)', 4, 1272, 3, Decimal('20.0'), 'STS-59 (Endeavor), STS-68 (Endeavor), STS-80 (Columbia), STS-98 (Atlantis)', '', ''),
#  ('Thomas H. Marshburn', 2004, 19, 'Active', '1960-08-29', 'Statesville, NC', 'Male', 'Davidson College; University of Virginia; Wake Forest University; University of Texas Medical Branch-Galveston', 'Physics', 'Engineering Physics; Medicine; Medical Science', 'Colonel', 'US Air Force (Retired)', 2, 3871, 4, Decimal('24.0'), 'STS-127 (Endeavor), ISS-34/35 (Soyuz)', '', ''),
#  ('Thomas K. Mattingly II', 1966, 5, 'Retired', '1936-03-17', 'Chicago, IL', 'Male', 'Auburn University', 'Aeronautical Engineering', 'Engineering Physics; Medicine; Medical Science', 'Rear Admiral', 'US Navy (Retired)', 3, 508, 1, Decimal('1.0'), 'Apollo 16, STS-4 (Columbia), STS 51-C (Discovery)', '', ''),
#  ('Thomas P. Stafford', 1962, 2, 'Retired', '1930-09-17', 'Weatherford, OK', 'Male', 'US Naval Academy', 'Aeronautical Engineering', 'Engineering Physics; Medicine; Medical Science', 'Lieutenant General', 'US Air Force (Retired)', 4, 507, 0, Decimal('0.0'), 'Gemini 6, Gemini 9, Apollo 10, Apollo-Soyuz Test Project', '', ''),
#  ('Timothy J. Creamer', 1998, 17, 'Management', '1959-11-15', 'Ft. Huachuca, AZ', 'Male', 'Loyola College; MIT', 'Chemistry', 'Physics', 'Colonel', 'US Army (Retired)', 1, 3917, 0, Decimal('0.0'), 'ISS-22/23 (Soyuz)', '', ''),
#  ('Timothy L. Kopra', 2000, 18, 'Active', '1963-04-09', 'Austin, TX', 'Male', 'US Military Academy; Georgia Institute of Technology; US Army War College', 'Computer Science', 'Aerospace Engineering; Strategic Studies', 'Colonel', 'US Army (Retired)', 2, 5857, 3, Decimal('13.0'), 'STS-127/128 (Endeavor/Discovery), ISS-46/47 (Soyuz)', '', ''),
#  ('Tracy E. Caldwell (Dyson)', 1998, 17, 'Active', '1969-08-14', 'Arcadia, CA', 'Female', 'California State University-Fullerton; University of California-Davis', 'Chemistry', 'Physical Chemistry', 'Colonel', 'US Army (Retired)', 2, 4531, 3, Decimal('23.0'), 'STS-118 (Endeavor), ISS-23/24 (Soyuz)', '', ''),
#  ('Vance D. Brand', 1966, 5, 'Retired', '1931-05-09', 'Longmont, CA', 'Male', 'University of Colorado; University of California Los Angeles', 'Business Management; Aeronautical Engineering', 'Business Administration', 'Colonel', 'US Marine Corps Reserves', 4, 752, 0, Decimal('0.0'), 'Apollo-Soyuz Test Project, STS-5 (Columbia), STS 41-B (Challenger), STS-35 (Columbia)', '', ''),
#  ('Virgil I. Grissom', 1959, 1, 'Deceased', '1926-04-03', 'Mitchell, IN', 'Male', 'Purdue University', 'Mechanical Engineering', 'Business Administration', 'Lieutenant Colonel', 'US Air Force', 2, 5, 0, Decimal('0.0'), 'Mercury 4, Gemini 3, Apollo 1', '1967-01-27', 'Apollo 1'),
#  ('Walter Cunningham', 1963, 3, 'Retired', '1932-03-16', 'Creston, IA', 'Male', 'University of California-Los Angeles', 'Physics', 'Physics', 'Colonel', 'US Marine Corps Reserves', 1, 260, 0, Decimal('0.0'), 'Apollo 7', '', ''),
#  ('Walter M. Schirra Jr.', 1959, 1, 'Deceased', '1923-03-12', 'Hackensack, NJ', 'Male', 'US Naval Academy', 'Naval Sciences', 'Physics', 'Captain', 'US Navy (Retired)', 3, 295, 0, Decimal('0.0'), 'Mercury 8, Gemini 6, Apollo 7', '2007-05-02', 'Natural causes'),
#  ('Wendy B. Lawrence', 1992, 14, 'Retired', '1959-07-02', 'Jacksonville, FL', 'Female', 'US Naval Academy; MIT', 'Ocean Engineering', 'Ocean Engineering', 'Captain', 'US Navy (Retired)', 4, 1223, 0, Decimal('0.0'), 'STS-67 (Endeavor), STS-86 (Atlantis), STS-91 (Discovery), STS-114 (Discovery)', '', ''),
#  ('William A. Anders', 1963, 3, 'Retired', '1933-10-17', 'Hong Kong', 'Male', 'US Naval Academy; Air Force Institute of Technology', 'Nuclear Engineering', 'Nuclear Engineering', 'Major General', 'US Air Force Reserves (Retired)', 1, 147, 0, Decimal('0.0'), 'Apollo 8', '', ''),
#  ('William A. Oefelein', 1998, 17, 'Retired', '1965-03-29', 'Ft. Belvoir, VA', 'Male', 'Oregon State University; University of Tennessee', 'Electrical Engineering', 'Aviation Systems', 'Commander', 'US Navy (Retired)', 1, 308, 0, Decimal('0.0'), 'STS-116 (Discovery)', '', ''),
#  ('William A. Pailes', 1998, 17, 'Retired', '1952-06-26', 'Hackensack, NJ', 'Male', 'US Air Force Academy; Texas A&M University', 'Computer Science', 'Computer Science', 'Colonel', 'US Air Force (Retired)', 1, 97, 0, Decimal('0.0'), 'STS 51-J (Atlantis)', '', ''),
#  ('William B. Lenoir', 1967, 6, 'Deceased', '1939-03-14', 'Miami, FL', 'Male', 'MIT', 'Electrical Engineering', 'Electrical Engineering', 'Colonel', 'US Air Force (Retired)', 1, 122, 0, Decimal('0.0'), 'STS-5 (Columbia)', '2010-08-26', 'Natural causes'),
#  ('William C. McCool', 1996, 16, 'Deceased', '1961-09-23', 'San Diego, CA', 'Male', 'US Naval Academy; University of Maryland; US Naval Postgraduate School', 'Naval Sciences', 'Computer Science; Aeronautical Engineering', 'Commander', 'US Navy', 1, 382, 0, Decimal('0.0'), 'STS-107 (Columbia)', '2003-02-01', 'STS-107 (Columbia)'),
#  ('William E. Thornton', 1967, 6, 'Retired', '1929-04-14', 'Faison, NC', 'Male', 'University of North Carolina', 'Physics', 'Medicine', 'Commander', 'US Navy', 2, 315, 0, Decimal('0.0'), 'STS-8 (Challenger), STS 51-B (Challenger)', '', ''),
#  ('William F. Fisher', 1980, 9, 'Retired', '1946-04-01', 'Dallas, TX', 'Male', 'Stanford University; University of Houston; University of Florida', 'Physics', 'Engineering; Medicine', 'Commander', 'US Navy', 1, 170, 2, Decimal('12.0'), 'STS 51-I (Discovery)', '', ''),
#  ('William F. Readdy', 1987, 12, 'Retired', '1952-01-24', 'Quonset Point, RI', 'Male', 'US Naval Academy', 'Aerospace Engineering', 'Engineering; Medicine', 'Captain', 'US Navy (Retired)', 3, 672, 0, Decimal('0.0'), 'STS-42 (Discovery), STS-51 (Discovery), STS-79 (Atlantis)', '', ''),
#  ('William G. Gregory', 1990, 13, 'Retired', '1957-05-14', 'Lockport, NY', 'Male', 'US Air Force Academy; Columbia University; Troy State University', 'Engineering Science', 'Engineering Mechanics; Business Management', 'Lieutenant Colonel', 'US Air Force', 1, 399, 0, Decimal('0.0'), 'STS-67 (Endeavor)', '', ''),
#  ('William M. Shepherd', 1984, 10, 'Retired', '1949-07-26', 'Oak Ridge, TN', 'Male', 'US Naval Academy; MIT', 'Aerospace Engineering', 'Mechanical  Engineering', 'Captain', 'US Navy (Retired)', 4, 3823, 0, Decimal('0.0'), 'STS-37 (Atlantis), STS-41 (Discovery), STS-52 (Columbia), ISS-01/STS-102 (Soyuz/Discovery)', '', ''),
#  ('William R. Pogue', 1966, 5, 'Retired', '1930-01-23', 'Okemah, OK', 'Male', 'Oklahoma Baptist University; Oklahoma State University', 'Education', 'Mathematics', 'Colonel', 'US Air Force (Retired)', 1, 2017, 2, Decimal('13.0'), 'Skylab 4', '', ''),
#  ('William S. McArthur Jr.', 1990, 3, 'Management', '1951-07-26', 'Laurinburg, NC', 'Male', 'US Military Academy; Georgia Institute of Technology', 'Applied Science & Engineering', 'Aerospace Engineering', 'Colonel', 'US Army (Retired)', 4, 5398, 4, Decimal('24.0'), 'STS-58 (Columbia), STS-74 (Atlantis), STS-92 (Discovery), ISS-12 (Soyuz)', '', ''),
#  ('Winston E. Scott', 1992, 14, 'Retired', '1950-08-06', 'Miami, FL', 'Male', 'Florida State University; US Naval Postgraduate School', 'Music', 'Aeronautical Engineering', 'Captain', 'US Navy (Retired)', 2, 590, 3, Decimal('19.0'), 'STS-72 (Endeavor), STS-87 (Columbia)', '', ''),
#  ('Yvonne D. Cagle', 1996, 16, 'Management', '1959-04-24', 'West Point, NY', 'Female', 'San Francisco State University', 'Biochemistry', 'Aeronautical Engineering', 'Colonel', 'US Air Force', 0, 0, 0, Decimal('0.0'), 'STS-72 (Endeavor), STS-87 (Columbia)', '', '')]

# %% [markdown]
# ### Counting astronauts based on their status.

# %%
# %%sql
# SELECT Status, count(*) as Number
# from astronauts
# group by Status;
# Out:
#  * mysql://root:***@localhost/nasa
# 4 rows affected.
# [('Active', 50), ('Deceased', 48), ('Management', 36), ('Retired', 216)]

# %% [markdown]
# ### Counting astronauts by military branch

# %%
# %%sql
# SELECT Military_Branch, count(*) as "Number"
# From astronauts
# GROUP BY Military_Branch;
# Out:
#  * mysql://root:***@localhost/nasa
# 14 rows affected.
# [('US Air Force', 26),
#  ('US Air Force (Retired)', 108),
#  ('US Air Force Reserves', 3),
#  ('US Air Force Reserves (Retired)', 3),
#  ('US Army', 10),
#  ('US Army (Retired)', 21),
#  ('US Coast Guard (Retired)', 4),
#  ('US Marine Corps', 3),
#  ('US Marine Corps (Retired)', 29),
#  ('US Marine Corps Reserves', 2),
#  ('US Naval Reserves', 2),
#  ('US Naval Reserves (Retired)', 2),
#  ('US Navy', 37),
#  ('US Navy (Retired)', 100)]

# %% [markdown]
# ### Top 5 Military ranks among astronauts.

# %%
# %%sql
# SELECT Military_Rank, count(*) as 'Number'
# FROM astronauts
# GROUP BY Military_Rank
# ORDER BY 2 DESC
# LIMIT 5;
# Out:
#  * mysql://root:***@localhost/nasa
# 5 rows affected.
# [('Colonel', 155),
#  ('Captain', 115),
#  ('Commander', 26),
#  ('Lieutenant Colonel', 17),
#  ('Major General', 12)]

# %% [markdown]
# ### Exploring Astronaut Demographics: Gender Insights

# %% [markdown]
# ### Count of Astronauts by Gender

# %%
# %%sql
# SELECT Gender, count(*) as 'Number'
# FROM astronauts
# GROUP By Gender;
# Out:
#  * mysql://root:***@localhost/nasa
# 2 rows affected.
# [('Female', 49), ('Male', 301)]

# %% [markdown]
# ## Life Expectancy of Astronauts.

# %% [markdown]
# ### Average Life Expectancy of Astronauts.

# %%
# %%sql
# SELECT CEILING(AVG(Life_Expectancy)) as 'Average_Life_Expectancy'
#
# FROM (SELECT (CASE
#  WHEN Status ='Deceased' THEN (YEAR(Death_Date) - Year(Birth_Date))
#  ELSE (2023 - Year(Birth_Date) )
# END) AS "Life_Expectancy"
#  FROM astronauts )Average_L;
# Out:
#  * mysql://root:***@localhost/nasa
# 1 rows affected.
# [(69,)]

# %% [markdown]
# ### Average Life Expectancy of Female Astronauts.

# %%
# %%sql
#
# SELECT CEILING(AVG(Life_Expectancy)) as 'Female_Life_Expectancy'
#
# FROM (
# SELECT (CASE
#  WHEN Status ='Deceased' THEN (YEAR(Death_Date) - Year(Birth_Date))
#  ELSE (2023 - Year(Birth_Date) )
# END) AS "Life_Expectancy", Gender
#  FROM astronauts
# WHERE Gender = "Female")Average_F;
# Out:
#  * mysql://root:***@localhost/nasa
# 1 rows affected.
# [(62,)]

# %% [markdown]
# ### Average Life Expectancy of Male Astronauts.

# %%
# %%sql
#
# SELECT CEILING(AVG(Life_Expectancy)) as 'Male_Life_Expectancy'
#
# FROM (
# SELECT (CASE
#  WHEN Status ='Deceased' THEN (YEAR(Death_Date) - Year(Birth_Date))
#  ELSE (2023 - Year(Birth_Date) )
# END) AS "Life_Expectancy", Gender
#  FROM astronauts
# WHERE Gender = "Male")Average_M;
# Out:
#  * mysql://root:***@localhost/nasa
# 1 rows affected.
# [(70,)]

# %% [markdown]
# ### Top 10 Graduate Majors Among Astronauts.

# %%
# %%sql
#
# SELECT Graduate_Major, count(*) as ' Number'
# FROM astronauts
# GROUP BY Graduate_Major
# ORDER BY 2 DESC
# LIMIT 10;
# Out:
#  * mysql://root:***@localhost/nasa
# 10 rows affected.
# [('Aeronautical Engineering', 34),
#  ('Aerospace Engineering', 26),
#  ('Physics', 17),
#  ('Medicine', 16),
#  ('Mechanical Engineering', 14),
#  ('Electrical Engineering', 9),
#  ('Astronautics', 8),
#  ('Aeronautics', 7),
#  ('Aviation Systems', 7),
#  ('Aeronautics & Astronautics', 7)]

# %% [markdown]
# ### Astronaut Education Statistics.

# %%
# %%sql
# SELECT count(*) as ' Number_of_Astronauts.', count(*) as 'Astronauts_with_Undergraduate_Degrees.', count(*) as 'Astronauts_with_Graduate_Degrees.'
# FROM astronauts;
# Out:
#  * mysql://root:***@localhost/nasa
# 1 rows affected.
# [(350, 350, 350)]

# %% [markdown]
# ### Top 5 States of Birth for Astronauts.

# %%
# %%sql
# SELECT SUBSTRING_INDEX(Birth_Place, ',',-1) as 'STATE', count(*) as 'Number'
# FROM astronauts
# GROUP By SUBSTRING_INDEX(Birth_Place, ',',-1)
# ORDER BY 2 DESC
# LIMIT 5;
# Out:
#  * mysql://root:***@localhost/nasa
# 5 rows affected.
# [(' NY', 30), (' CA', 25), (' TX', 23), (' OH', 21), (' PA', 19)]

# %% [markdown]
# ### Average Space Flights and Spacewalks per Astronaut.

# %%
# %%sql
#
# SELECT ROUND(AVG(Space_Flights), 2) as 'Average_Number_Of_Space_Flight.', ROUND(AVG(Space_Walks), 2) 'Average_Number_Of_Space_Walks.'
# FROM astronauts;
# Out:
#  * mysql://root:***@localhost/nasa
# 1 rows affected.
# [(Decimal('2.40'), Decimal('1.27'))]
